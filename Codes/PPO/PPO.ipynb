# %%
import gymnasium as gym
from stable_baselines3 import DDPG,PPO

# %%
env = gym.make("HalfCheetah-v5", render_mode="human")  # Set render_mode to None for training
obs, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample()  # Take random actions
    obs, reward, done, truncated, info = env.step(action)

env.close()

# %%
env = gym.make("HalfCheetah-v4")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1_000_000)
model.save("ppo_halfcheetah")
# Out:
# c:\Users\Rishub\anaconda3\envs\rlenv\lib\site-packages\gymnasium\envs\registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -335     |
# | time/              |          |
# |    fps             | 2804     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -385        |
# | time/                   |             |
# |    fps                  | 1972        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009834007 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.5        |
# |    explained_variance   | -0.0212     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.023      |
# |    std                  | 0.996       |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 1781        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010651268 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.993       |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 1692        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008646114 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.987       |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -351        |
# | time/                   |             |
# |    fps                  | 1651        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008332512 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.44       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.986       |
# |    value_loss           | 33.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 1618        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007868818 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.98        |
# |    value_loss           | 26.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -344         |
# | time/                   |              |
# |    fps                  | 1604         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0111547895 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.38        |
# |    explained_variance   | 0.31         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.36         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0261      |
# |    std                  | 0.976        |
# |    value_loss           | 15.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 1588        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011153628 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.973       |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 1575        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008237782 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.972       |
# |    value_loss           | 46.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 1566        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008081768 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.34       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.97        |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -347        |
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 11          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014297355 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.31       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.77        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 0.963       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -343        |
# | time/                   |             |
# |    fps                  | 1546        |
# |    iterations           | 12          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013767956 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.0582      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0324     |
# |    std                  | 0.957       |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 1540        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007881306 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.73        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.956       |
# |    value_loss           | 21.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -337        |
# | time/                   |             |
# |    fps                  | 1536        |
# |    iterations           | 14          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009497769 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.23       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.952       |
# |    value_loss           | 27.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 1529        |
# |    iterations           | 15          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012005724 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.19       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.76        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.944       |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -331       |
# | time/                   |            |
# |    fps                  | 1521       |
# |    iterations           | 16         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01275745 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.16      |
# |    explained_variance   | 0.434      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.28       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0372    |
# |    std                  | 0.941      |
# |    value_loss           | 13.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -323        |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 17          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010346632 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.45        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.936       |
# |    value_loss           | 16.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -319       |
# | time/                   |            |
# |    fps                  | 1516       |
# |    iterations           | 18         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01278526 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.12      |
# |    explained_variance   | 0.428      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.22       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0343    |
# |    std                  | 0.935      |
# |    value_loss           | 15.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -318       |
# | time/                   |            |
# |    fps                  | 1514       |
# |    iterations           | 19         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01681164 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.09      |
# |    explained_variance   | 0.0958     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.41       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0415    |
# |    std                  | 0.929      |
# |    value_loss           | 13.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 1513        |
# |    iterations           | 20          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011776434 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.06       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.46        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0331     |
# |    std                  | 0.925       |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -309        |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 21          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009309885 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.04       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.923       |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 1518        |
# |    iterations           | 22          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011043815 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0304     |
# |    std                  | 0.921       |
# |    value_loss           | 23.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 1517        |
# |    iterations           | 23          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016655397 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.31        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.914       |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -301        |
# | time/                   |             |
# |    fps                  | 1514        |
# |    iterations           | 24          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015108131 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.57        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.039      |
# |    std                  | 0.914       |
# |    value_loss           | 15          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -299        |
# | time/                   |             |
# |    fps                  | 1509        |
# |    iterations           | 25          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015401011 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0368     |
# |    std                  | 0.912       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 26          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.016388405 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0398     |
# |    std                  | 0.905       |
# |    value_loss           | 13          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -299         |
# | time/                   |              |
# |    fps                  | 1495         |
# |    iterations           | 27           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0154197775 |
# |    clip_fraction        | 0.162        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.88        |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0374      |
# |    std                  | 0.896        |
# |    value_loss           | 17.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -295        |
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 28          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009714505 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.84       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.893       |
# |    value_loss           | 55.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 1471        |
# |    iterations           | 29          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013795957 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.27        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.886       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -288        |
# | time/                   |             |
# |    fps                  | 1463        |
# |    iterations           | 30          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016772132 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.883       |
# |    value_loss           | 15.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -286        |
# | time/                   |             |
# |    fps                  | 1457        |
# |    iterations           | 31          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.015569983 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.75       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.039      |
# |    std                  | 0.879       |
# |    value_loss           | 18.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -283        |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 32          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017206479 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.73       |
# |    explained_variance   | 0.489       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0457     |
# |    std                  | 0.875       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -282        |
# | time/                   |             |
# |    fps                  | 1447        |
# |    iterations           | 33          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011356911 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.032      |
# |    std                  | 0.87        |
# |    value_loss           | 28.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 34          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.020694543 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.64       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.28        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.044      |
# |    std                  | 0.863       |
# |    value_loss           | 14          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -278       |
# | time/                   |            |
# |    fps                  | 1434       |
# |    iterations           | 35         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02284845 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.61      |
# |    explained_variance   | 0.293      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.69       |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0486    |
# |    std                  | 0.858      |
# |    value_loss           | 8.48       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -276        |
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 36          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012686484 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.58       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.854       |
# |    value_loss           | 25.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -274        |
# | time/                   |             |
# |    fps                  | 1422        |
# |    iterations           | 37          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.024321651 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.5        |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0523     |
# |    std                  | 0.84        |
# |    value_loss           | 10.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -271       |
# | time/                   |            |
# |    fps                  | 1418       |
# |    iterations           | 38         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01947096 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.46      |
# |    explained_variance   | 0.21       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.91       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0499    |
# |    std                  | 0.838      |
# |    value_loss           | 11.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -267        |
# | time/                   |             |
# |    fps                  | 1415        |
# |    iterations           | 39          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.018478315 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.42       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.92        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0452     |
# |    std                  | 0.832       |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -264        |
# | time/                   |             |
# |    fps                  | 1412        |
# |    iterations           | 40          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.020059556 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.38       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.54        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0477     |
# |    std                  | 0.825       |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -259        |
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 41          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021324161 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0487     |
# |    std                  | 0.82        |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -254        |
# | time/                   |             |
# |    fps                  | 1407        |
# |    iterations           | 42          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019477267 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.3        |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.47        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0457     |
# |    std                  | 0.813       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -250        |
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 43          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016453035 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.25       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.08        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0417     |
# |    std                  | 0.809       |
# |    value_loss           | 17.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -246        |
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 44          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016148377 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.21       |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0464     |
# |    std                  | 0.8         |
# |    value_loss           | 18.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -242      |
# | time/                   |           |
# |    fps                  | 1394      |
# |    iterations           | 45        |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0145087 |
# |    clip_fraction        | 0.165     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.16     |
# |    explained_variance   | 0.302     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 12.6      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0432   |
# |    std                  | 0.796     |
# |    value_loss           | 23.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -239        |
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 46          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.018532967 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0446     |
# |    std                  | 0.788       |
# |    value_loss           | 17.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -232        |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 47          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.015361171 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.07       |
# |    explained_variance   | 0.503       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0415     |
# |    std                  | 0.785       |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -227        |
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 48          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022324951 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.03       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.77        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.051      |
# |    std                  | 0.778       |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -222        |
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 49          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.023330081 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.97       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.16        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0532     |
# |    std                  | 0.769       |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -213        |
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 50          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.022636684 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.88       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.32        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0488     |
# |    std                  | 0.759       |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -202       |
# | time/                   |            |
# |    fps                  | 1375       |
# |    iterations           | 51         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02101416 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.83      |
# |    explained_variance   | 0.299      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.48       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.054     |
# |    std                  | 0.753      |
# |    value_loss           | 16.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 1376        |
# |    iterations           | 52          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.022154927 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.77       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.88        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0501     |
# |    std                  | 0.744       |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -184        |
# | time/                   |             |
# |    fps                  | 1372        |
# |    iterations           | 53          |
# |    time_elapsed         | 79          |
# ...
# | train/                  |            |
# |    approx_kl            | 0.10887644 |
# |    clip_fraction        | 0.585      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.11       |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.22       |
# |    n_updates            | 4710       |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.175      |
# |    value_loss           | 13.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.42e+03    |
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 473         |
# |    time_elapsed         | 692         |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.103163004 |
# |    clip_fraction        | 0.551       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.14        |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.19        |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.175       |
# |    value_loss           | 12.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.42e+03   |
# | time/                   |            |
# |    fps                  | 1398       |
# |    iterations           | 474        |
# |    time_elapsed         | 694        |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.09754109 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.16       |
# |    explained_variance   | 0.841      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.18       |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.0157    |
# |    std                  | 0.173      |
# |    value_loss           | 12.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.42e+03   |
# | time/                   |            |
# |    fps                  | 1398       |
# |    iterations           | 475        |
# |    time_elapsed         | 695        |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.07964343 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.16       |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.46       |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.0104    |
# |    std                  | 0.174      |
# |    value_loss           | 11.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.42e+03    |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 476         |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.087549046 |
# |    clip_fraction        | 0.532       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.15        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.23        |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.174       |
# |    value_loss           | 11          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 1.42e+03  |
# | time/                   |           |
# |    fps                  | 1397      |
# |    iterations           | 477       |
# |    time_elapsed         | 698       |
# |    total_timesteps      | 976896    |
# | train/                  |           |
# |    approx_kl            | 0.0710797 |
# |    clip_fraction        | 0.507     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.15      |
# |    explained_variance   | 0.805     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.66      |
# |    n_updates            | 4760      |
# |    policy_gradient_loss | -0.0265   |
# |    std                  | 0.174     |
# |    value_loss           | 14.5      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 1397       |
# |    iterations           | 478        |
# |    time_elapsed         | 700        |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.04992345 |
# |    clip_fraction        | 0.453      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.14       |
# |    explained_variance   | 0.864      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.51       |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.175      |
# |    value_loss           | 17.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.43e+03    |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 479         |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.107308075 |
# |    clip_fraction        | 0.574       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.12        |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.59        |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.175       |
# |    value_loss           | 9.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.43e+03    |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 480         |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.102981225 |
# |    clip_fraction        | 0.569       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.12        |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.174       |
# |    value_loss           | 9.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 1397       |
# |    iterations           | 481        |
# |    time_elapsed         | 704        |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.07814869 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.16       |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.26       |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.0236    |
# |    std                  | 0.173      |
# |    value_loss           | 10.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.43e+03    |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 482         |
# |    time_elapsed         | 706         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.053488627 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.18        |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.6         |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.173       |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.43e+03    |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 483         |
# |    time_elapsed         | 708         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.030039987 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.19        |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.85        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0366     |
# |    std                  | 0.173       |
# |    value_loss           | 41.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.44e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 484        |
# |    time_elapsed         | 709        |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.09622355 |
# |    clip_fraction        | 0.531      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.21       |
# |    explained_variance   | 0.866      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.28       |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.0203    |
# |    std                  | 0.172      |
# |    value_loss           | 14.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.44e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 485        |
# |    time_elapsed         | 711        |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.07778662 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.21       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.77       |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0185    |
# |    std                  | 0.172      |
# |    value_loss           | 16         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.44e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 486        |
# |    time_elapsed         | 712        |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.10410477 |
# |    clip_fraction        | 0.557      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.21       |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.5        |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0164    |
# |    std                  | 0.172      |
# |    value_loss           | 12.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 487        |
# |    time_elapsed         | 714        |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.09482442 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.21       |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.11       |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0161    |
# |    std                  | 0.173      |
# |    value_loss           | 11.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 488        |
# |    time_elapsed         | 715        |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.05820327 |
# |    clip_fraction        | 0.496      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.21       |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.37       |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.021     |
# |    std                  | 0.172      |
# |    value_loss           | 20.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 489        |
# |    time_elapsed         | 717        |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.13983662 |
# |    clip_fraction        | 0.603      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.22       |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.02       |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.00824   |
# |    std                  | 0.172      |
# |    value_loss           | 9.72       |
# ----------------------------------------

# %%
model = PPO.load("ppo_halfcheetah_800000_steps.zip")

print(model.policy)
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=17, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=17, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=6, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
import matplotlib.pyplot as plt
import time

env = gym.make("HalfCheetah-v5", render_mode="human")
obs, _ = env.reset()


rewards = []

# Run the model
for _ in range(3000):
    action, _states = model.predict(obs)
    obs, reward, done, truncated, info = env.step(action)
    # print(reward)
    rewards.append(reward)
    print(info)

    if done or truncated:
        obs, _ = env.reset()
        print("done==========================")
        # print(_)
    
   

env.close()

# Plot the rewards
plt.plot(rewards)
plt.title("Reward per Step (HalfCheetah)")
plt.xlabel("Timestep")
plt.ylabel("Reward")
plt.grid(True)
plt.show()
# Out:
# {'x_position': np.float64(0.0990601976863068), 'x_velocity': np.float64(0.01147698878936676), 'reward_forward': np.float64(0.01147698878936676), 'reward_ctrl': np.float32(-0.21463457)}
# {'x_position': np.float64(0.10250905870018046), 'x_velocity': np.float64(0.068977220277473), 'reward_forward': np.float64(0.068977220277473), 'reward_ctrl': np.float32(-0.46346933)}
# {'x_position': np.float64(0.06970357787661387), 'x_velocity': np.float64(-0.6561096164713317), 'reward_forward': np.float64(-0.6561096164713317), 'reward_ctrl': np.float32(-0.1276366)}
# {'x_position': np.float64(0.07046162466081321), 'x_velocity': np.float64(0.015160935683986854), 'reward_forward': np.float64(0.015160935683986854), 'reward_ctrl': np.float32(-0.10381557)}
# {'x_position': np.float64(0.13545774944560446), 'x_velocity': np.float64(1.2999224956958249), 'reward_forward': np.float64(1.2999224956958249), 'reward_ctrl': np.float32(-0.17405862)}
# {'x_position': np.float64(0.17817279863492427), 'x_velocity': np.float64(0.8543009837863963), 'reward_forward': np.float64(0.8543009837863963), 'reward_ctrl': np.float32(-0.15969673)}
# {'x_position': np.float64(0.1633951172185404), 'x_velocity': np.float64(-0.29555362832767773), 'reward_forward': np.float64(-0.29555362832767773), 'reward_ctrl': np.float32(-0.22632127)}
# {'x_position': np.float64(0.17701717099833977), 'x_velocity': np.float64(0.27244107559598774), 'reward_forward': np.float64(0.27244107559598774), 'reward_ctrl': np.float32(-0.25089005)}
# {'x_position': np.float64(0.2599100879141871), 'x_velocity': np.float64(1.657858338316947), 'reward_forward': np.float64(1.657858338316947), 'reward_ctrl': np.float32(-0.28855103)}
# {'x_position': np.float64(0.37446988719657537), 'x_velocity': np.float64(2.291195985647765), 'reward_forward': np.float64(2.291195985647765), 'reward_ctrl': np.float32(-0.2498257)}
# {'x_position': np.float64(0.43949979471266876), 'x_velocity': np.float64(1.3005981503218678), 'reward_forward': np.float64(1.3005981503218678), 'reward_ctrl': np.float32(-0.36252365)}
# {'x_position': np.float64(0.44198400420389444), 'x_velocity': np.float64(0.049684189824513725), 'reward_forward': np.float64(0.049684189824513725), 'reward_ctrl': np.float32(-0.3733657)}
# {'x_position': np.float64(0.514021764916133), 'x_velocity': np.float64(1.4407552142447722), 'reward_forward': np.float64(1.4407552142447722), 'reward_ctrl': np.float32(-0.2774461)}
# {'x_position': np.float64(0.6621723902168568), 'x_velocity': np.float64(2.963012506014475), 'reward_forward': np.float64(2.963012506014475), 'reward_ctrl': np.float32(-0.1900537)}
# {'x_position': np.float64(0.7645089265098014), 'x_velocity': np.float64(2.046730725858892), 'reward_forward': np.float64(2.046730725858892), 'reward_ctrl': np.float32(-0.19419466)}
# {'x_position': np.float64(0.7907887103033527), 'x_velocity': np.float64(0.5255956758710267), 'reward_forward': np.float64(0.5255956758710267), 'reward_ctrl': np.float32(-0.35861763)}
# {'x_position': np.float64(0.8727132919740029), 'x_velocity': np.float64(1.638491633413004), 'reward_forward': np.float64(1.638491633413004), 'reward_ctrl': np.float32(-0.3614433)}
# {'x_position': np.float64(1.0465558481800654), 'x_velocity': np.float64(3.4768511241212496), 'reward_forward': np.float64(3.4768511241212496), 'reward_ctrl': np.float32(-0.15657221)}
# {'x_position': np.float64(1.1840877983198255), 'x_velocity': np.float64(2.750639002795201), 'reward_forward': np.float64(2.750639002795201), 'reward_ctrl': np.float32(-0.24024773)}
# {'x_position': np.float64(1.240455762367868), 'x_velocity': np.float64(1.1273592809608513), 'reward_forward': np.float64(1.1273592809608513), 'reward_ctrl': np.float32(-0.38387156)}
# {'x_position': np.float64(1.2853651010674547), 'x_velocity': np.float64(0.8981867739917337), 'reward_forward': np.float64(0.8981867739917337), 'reward_ctrl': np.float32(-0.21383324)}
# {'x_position': np.float64(1.3903207881112516), 'x_velocity': np.float64(2.0991137408759375), 'reward_forward': np.float64(2.0991137408759375), 'reward_ctrl': np.float32(-0.15082927)}
# {'x_position': np.float64(1.5379196507358763), 'x_velocity': np.float64(2.9519772524924948), 'reward_forward': np.float64(2.9519772524924948), 'reward_ctrl': np.float32(-0.24813044)}
# {'x_position': np.float64(1.6319796395708446), 'x_velocity': np.float64(1.881199776699365), 'reward_forward': np.float64(1.881199776699365), 'reward_ctrl': np.float32(-0.25479236)}
# {'x_position': np.float64(1.6530300506698064), 'x_velocity': np.float64(0.4210082219792355), 'reward_forward': np.float64(0.4210082219792355), 'reward_ctrl': np.float32(-0.13641897)}
# {'x_position': np.float64(1.665300108560996), 'x_velocity': np.float64(0.24540115782379246), 'reward_forward': np.float64(0.24540115782379246), 'reward_ctrl': np.float32(-0.25770876)}
# {'x_position': np.float64(1.7626763681168571), 'x_velocity': np.float64(1.947525191117223), 'reward_forward': np.float64(1.947525191117223), 'reward_ctrl': np.float32(-0.18058395)}
# {'x_position': np.float64(1.8953972618090453), 'x_velocity': np.float64(2.654417873843764), 'reward_forward': np.float64(2.654417873843764), 'reward_ctrl': np.float32(-0.25733534)}
# {'x_position': np.float64(1.975574194121846), 'x_velocity': np.float64(1.6035386462560153), 'reward_forward': np.float64(1.6035386462560153), 'reward_ctrl': np.float32(-0.34752718)}
# {'x_position': np.float64(1.9956262620857568), 'x_velocity': np.float64(0.4010413592782136), 'reward_forward': np.float64(0.4010413592782136), 'reward_ctrl': np.float32(-0.23257677)}
# {'x_position': np.float64(2.0437288965882265), 'x_velocity': np.float64(0.9620526900493953), 'reward_forward': np.float64(0.9620526900493953), 'reward_ctrl': np.float32(-0.30880758)}
# {'x_position': np.float64(2.169495236199809), 'x_velocity': np.float64(2.515326792231649), 'reward_forward': np.float64(2.515326792231649), 'reward_ctrl': np.float32(-0.24738431)}
# {'x_position': np.float64(2.320593016213148), 'x_velocity': np.float64(3.021955600266777), 'reward_forward': np.float64(3.021955600266777), 'reward_ctrl': np.float32(-0.34017685)}
# {'x_position': np.float64(2.415065773888676), 'x_velocity': np.float64(1.8894551535105641), 'reward_forward': np.float64(1.8894551535105641), 'reward_ctrl': np.float32(-0.38797003)}
# {'x_position': np.float64(2.4389909674655796), 'x_velocity': np.float64(0.47850387153807183), 'reward_forward': np.float64(0.47850387153807183), 'reward_ctrl': np.float32(-0.3071049)}
# {'x_position': np.float64(2.5413673827582404), 'x_velocity': np.float64(2.0475283058532145), 'reward_forward': np.float64(2.0475283058532145), 'reward_ctrl': np.float32(-0.292615)}
# {'x_position': np.float64(2.731024037524316), 'x_velocity': np.float64(3.793133095321517), 'reward_forward': np.float64(3.793133095321517), 'reward_ctrl': np.float32(-0.22312449)}
# {'x_position': np.float64(2.8737907283451376), 'x_velocity': np.float64(2.8553338164164277), 'reward_forward': np.float64(2.8553338164164277), 'reward_ctrl': np.float32(-0.304468)}
# {'x_position': np.float64(2.9078572481829847), 'x_velocity': np.float64(0.6813303967569428), 'reward_forward': np.float64(0.6813303967569428), 'reward_ctrl': np.float32(-0.41041565)}
# {'x_position': np.float64(2.9722927829227466), 'x_velocity': np.float64(1.2887106947952365), 'reward_forward': np.float64(1.2887106947952365), 'reward_ctrl': np.float32(-0.3050408)}
# {'x_position': np.float64(3.1707681967923427), 'x_velocity': np.float64(3.969508277391922), 'reward_forward': np.float64(3.969508277391922), 'reward_ctrl': np.float32(-0.34256014)}
# {'x_position': np.float64(3.3333898809841895), 'x_velocity': np.float64(3.252433683836937), 'reward_forward': np.float64(3.252433683836937), 'reward_ctrl': np.float32(-0.39743233)}
# {'x_position': np.float64(3.4174623141302405), 'x_velocity': np.float64(1.681448662921019), 'reward_forward': np.float64(1.681448662921019), 'reward_ctrl': np.float32(-0.319065)}
# {'x_position': np.float64(3.4932205984544877), 'x_velocity': np.float64(1.515165686484945), 'reward_forward': np.float64(1.515165686484945), 'reward_ctrl': np.float32(-0.33122346)}
# {'x_position': np.float64(3.6845476973767397), 'x_velocity': np.float64(3.8265419784450394), 'reward_forward': np.float64(3.8265419784450394), 'reward_ctrl': np.float32(-0.2847111)}
# {'x_position': np.float64(3.897828412675874), 'x_velocity': np.float64(4.265614305982686), 'reward_forward': np.float64(4.265614305982686), 'reward_ctrl': np.float32(-0.22876222)}
# {'x_position': np.float64(4.034284483436683), 'x_velocity': np.float64(2.7291214152161825), 'reward_forward': np.float64(2.7291214152161825), 'reward_ctrl': np.float32(-0.23343864)}
# {'x_position': np.float64(4.105814318163466), 'x_velocity': np.float64(1.4305966945356552), 'reward_forward': np.float64(1.4305966945356552), 'reward_ctrl': np.float32(-0.28260282)}
# {'x_position': np.float64(4.228822332691453), 'x_velocity': np.float64(2.4601602905597453), 'reward_forward': np.float64(2.4601602905597453), 'reward_ctrl': np.float32(-0.32566866)}
# {'x_position': np.float64(4.445090768439912), 'x_velocity': np.float64(4.32536871496918), 'reward_forward': np.float64(4.32536871496918), 'reward_ctrl': np.float32(-0.40203258)}
# {'x_position': np.float64(4.614494969270843), 'x_velocity': np.float64(3.3880840166186132), 'reward_forward': np.float64(3.3880840166186132), 'reward_ctrl': np.float32(-0.3417984)}
# {'x_position': np.float64(4.701232113659192), 'x_velocity': np.float64(1.7347428877669913), 'reward_forward': np.float64(1.7347428877669913), 'reward_ctrl': np.float32(-0.4004565)}
# {'x_position': np.float64(4.790834031866658), 'x_velocity': np.float64(1.7920383641493132), 'reward_forward': np.float64(1.7920383641493132), 'reward_ctrl': np.float32(-0.26547185)}
# {'x_position': np.float64(4.986075445581164), 'x_velocity': np.float64(3.904828274290111), 'reward_forward': np.float64(3.904828274290111), 'reward_ctrl': np.float32(-0.2904707)}
# {'x_position': np.float64(5.190700105346548), 'x_velocity': np.float64(4.092493195307689), 'reward_forward': np.float64(4.092493195307689), 'reward_ctrl': np.float32(-0.31755537)}
# {'x_position': np.float64(5.322452549386721), 'x_velocity': np.float64(2.6350488808034633), 'reward_forward': np.float64(2.6350488808034633), 'reward_ctrl': np.float32(-0.38495013)}
# {'x_position': np.float64(5.410997125793372), 'x_velocity': np.float64(1.7708915281330206), 'reward_forward': np.float64(1.7708915281330206), 'reward_ctrl': np.float32(-0.32562414)}
# {'x_position': np.float64(5.561262102369575), 'x_velocity': np.float64(3.0052995315240594), 'reward_forward': np.float64(3.0052995315240594), 'reward_ctrl': np.float32(-0.29156774)}
# {'x_position': np.float64(5.766684504577293), 'x_velocity': np.float64(4.108448044154365), 'reward_forward': np.float64(4.108448044154365), 'reward_ctrl': np.float32(-0.22630501)}
# {'x_position': np.float64(5.973689076601236), 'x_velocity': np.float64(4.140091440478848), 'reward_forward': np.float64(4.140091440478848), 'reward_ctrl': np.float32(-0.36334834)}
# {'x_position': np.float64(6.10379511683451), 'x_velocity': np.float64(2.602120804665482), 'reward_forward': np.float64(2.602120804665482), 'reward_ctrl': np.float32(-0.30909035)}
# {'x_position': np.float64(6.19708129178411), 'x_velocity': np.float64(1.8657234989919935), 'reward_forward': np.float64(1.8657234989919935), 'reward_ctrl': np.float32(-0.2658796)}
# {'x_position': np.float64(6.371517111925627), 'x_velocity': np.float64(3.4887164028303452), 'reward_forward': np.float64(3.4887164028303452), 'reward_ctrl': np.float32(-0.24169937)}
# {'x_position': np.float64(6.614905332273958), 'x_velocity': np.float64(4.8677644069666215), 'reward_forward': np.float64(4.8677644069666215), 'reward_ctrl': np.float32(-0.15692616)}
# {'x_position': np.float64(6.812355286721812), 'x_velocity': np.float64(3.948999088957077), 'reward_forward': np.float64(3.948999088957077), 'reward_ctrl': np.float32(-0.37419036)}
# {'x_position': np.float64(6.891631283577023), 'x_velocity': np.float64(1.5855199371042161), 'reward_forward': np.float64(1.5855199371042161), 'reward_ctrl': np.float32(-0.38342786)}
# {'x_position': np.float64(7.015760778625666), 'x_velocity': np.float64(2.482589900972876), 'reward_forward': np.float64(2.482589900972876), 'reward_ctrl': np.float32(-0.2440975)}
# {'x_position': np.float64(7.253574242791921), 'x_velocity': np.float64(4.756269283325096), 'reward_forward': np.float64(4.756269283325096), 'reward_ctrl': np.float32(-0.28355333)}
# {'x_position': np.float64(7.503391016939834), 'x_velocity': np.float64(4.9963354829582585), 'reward_forward': np.float64(4.9963354829582585), 'reward_ctrl': np.float32(-0.19448367)}
# {'x_position': np.float64(7.691998282610176), 'x_velocity': np.float64(3.7721453134068383), 'reward_forward': np.float64(3.7721453134068383), 'reward_ctrl': np.float32(-0.42115602)}
# {'x_position': np.float64(7.803049442818432), 'x_velocity': np.float64(2.2210232041651246), 'reward_forward': np.float64(2.2210232041651246), 'reward_ctrl': np.float32(-0.33517662)}
# {'x_position': np.float64(7.965408230365835), 'x_velocity': np.float64(3.2471757509480526), 'reward_forward': np.float64(3.2471757509480526), 'reward_ctrl': np.float32(-0.31083295)}
# {'x_position': np.float64(8.219181603832356), 'x_velocity': np.float64(5.0754674693304125), 'reward_forward': np.float64(5.0754674693304125), 'reward_ctrl': np.float32(-0.2304443)}
# {'x_position': np.float64(8.470161867667816), 'x_velocity': np.float64(5.019605276709207), 'reward_forward': np.float64(5.019605276709207), 'reward_ctrl': np.float32(-0.42670757)}
# {'x_position': np.float64(8.645609133745202), 'x_velocity': np.float64(3.5089453215477207), 'reward_forward': np.float64(3.5089453215477207), 'reward_ctrl': np.float32(-0.33770615)}
# {'x_position': np.float64(8.765714744683608), 'x_velocity': np.float64(2.4021122187681243), 'reward_forward': np.float64(2.4021122187681243), 'reward_ctrl': np.float32(-0.31291008)}
# {'x_position': np.float64(8.969244860435564), 'x_velocity': np.float64(4.070602315039125), 'reward_forward': np.float64(4.070602315039125), 'reward_ctrl': np.float32(-0.3167914)}
# {'x_position': np.float64(9.228992332940837), 'x_velocity': np.float64(5.194949450105462), 'reward_forward': np.float64(5.194949450105462), 'reward_ctrl': np.float32(-0.17144577)}
# {'x_position': np.float64(9.456175856279863), 'x_velocity': np.float64(4.543670466780512), 'reward_forward': np.float64(4.543670466780512), 'reward_ctrl': np.float32(-0.39479598)}
# {'x_position': np.float64(9.571983259767654), 'x_velocity': np.float64(2.316148069755819), 'reward_forward': np.float64(2.316148069755819), 'reward_ctrl': np.float32(-0.4244196)}
# {'x_position': np.float64(9.693472283314438), 'x_velocity': np.float64(2.4297804709356896), 'reward_forward': np.float64(2.4297804709356896), 'reward_ctrl': np.float32(-0.32710284)}
# {'x_position': np.float64(9.914863057761677), 'x_velocity': np.float64(4.427815488944766), 'reward_forward': np.float64(4.427815488944766), 'reward_ctrl': np.float32(-0.29482344)}
# {'x_position': np.float64(10.155577994410407), 'x_velocity': np.float64(4.814298732974613), 'reward_forward': np.float64(4.814298732974613), 'reward_ctrl': np.float32(-0.20931558)}
# {'x_position': np.float64(10.312454373569159), 'x_velocity': np.float64(3.1375275831750216), 'reward_forward': np.float64(3.1375275831750216), 'reward_ctrl': np.float32(-0.37502298)}
# {'x_position': np.float64(10.431379709696014), 'x_velocity': np.float64(2.3785067225371037), 'reward_forward': np.float64(2.3785067225371037), 'reward_ctrl': np.float32(-0.086175695)}
# {'x_position': np.float64(10.574880743050684), 'x_velocity': np.float64(2.8700206670934136), 'reward_forward': np.float64(2.8700206670934136), 'reward_ctrl': np.float32(-0.21197283)}
# {'x_position': np.float64(10.787433686530594), 'x_velocity': np.float64(4.251058869598197), 'reward_forward': np.float64(4.251058869598197), 'reward_ctrl': np.float32(-0.23887904)}
# {'x_position': np.float64(11.000503684795383), 'x_velocity': np.float64(4.26139996529578), 'reward_forward': np.float64(4.26139996529578), 'reward_ctrl': np.float32(-0.23624603)}
# {'x_position': np.float64(11.171802393205468), 'x_velocity': np.float64(3.425974168201691), 'reward_forward': np.float64(3.425974168201691), 'reward_ctrl': np.float32(-0.43794712)}
# {'x_position': np.float64(11.264280072578599), 'x_velocity': np.float64(1.8495535874626157), 'reward_forward': np.float64(1.8495535874626157), 'reward_ctrl': np.float32(-0.31321225)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      11 for _ in range(3000):
#      12     action, _states = model.predict(obs)
# ---> 13     obs, reward, done, truncated, info = env.step(action)
#      14     # print(reward)
#      15     rewards.append(reward)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\half_cheetah_v5.py:236, in HalfCheetahEnv.step(self, action)
#     233 info = {"x_position": x_position_after, "x_velocity": x_velocity, **reward_info}
#     235 if self.render_mode == "human":
# --> 236     self.render()
#     237 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     238 return observation, reward, False, False, info
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\mujoco_env.py:164, in MujocoEnv.render(self)
#     160 def render(self):
#     161     """
#     162     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     163     """
# --> 164     return self.mujoco_renderer.render(self.render_mode)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py:711, in MujocoRenderer.render(self, render_mode)
#     709     return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#     710 elif render_mode == "human":
# --> 711     return viewer.render()
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py:437, in WindowViewer.render(self)
#     435         self._loop_count = 1
#     436     while self._loop_count > 0:
# --> 437         update()
#     438         self._loop_count -= 1
#     440 # clear overlay
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py:418, in WindowViewer.render.<locals>.update()
#     408     for gridpos, [t1, t2] in self._overlays.items():
#     409         mujoco.mjr_overlay(
#     410             mujoco.mjtFontScale.mjFONTSCALE_150,
#     411             gridpos,
#    (...)
#     415             self.con,
#     416         )
# --> 418 glfw.swap_buffers(self.window)
#     419 glfw.poll_events()
#     420 self._time_per_render = 0.9 * self._time_per_render + 0.1 * (
#     421     time.time() - render_start
#     422 )
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\glfw\__init__.py:2380, in swap_buffers(window)
#    2373 def swap_buffers(window):
#    2374     """
#    2375     Swaps the front and back buffers of the specified window.
#    2376
#    2377     Wrapper for:
#    2378         void glfwSwapBuffers(GLFWwindow* window);
#    2379     """
# -> 2380     _glfw.glfwSwapBuffers(window)
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\glfw\__init__.py:687, in _prepare_errcheck.<locals>.errcheck(result, *args)
#     679 def _prepare_errcheck():
#     680     """
#     681     This function sets the errcheck attribute of all ctypes wrapped functions
#     682     to evaluate the _exc_info_from_callback global variable and re-raise any
#    (...)
#     685     using the _callback_exception_decorator.
#     686     """
# --> 687     def errcheck(result, *args):
#     688         global _exc_info_from_callback
#     689         if _exc_info_from_callback is not None:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\registration.py:740, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     739 try:
# --> 740     env = env_creator(**env_spec_kwargs)
#     741 except TypeError as e:
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\mujoco\half_cheetah_v5.py:187, in HalfCheetahEnv.__init__(self, xml_file, frame_skip, default_camera_config, forward_reward_weight, ctrl_cost_weight, reset_noise_scale, exclude_current_positions_from_observation, **kwargs)
#     183 self._exclude_current_positions_from_observation = (
#     184     exclude_current_positions_from_observation
#     185 )
# --> 187 MujocoEnv.__init__(
#     188     self,
#     189     xml_file,
#     190     frame_skip,
#     191     observation_space=None,
#     192     default_camera_config=default_camera_config,
#     193     **kwargs,
#     194 )
#     196 self.metadata = {
#     197     "render_modes": [
#     198         "human",
#    (...)
#     202     "render_fps": int(np.round(1.0 / self.dt)),
#     203 }
#
# TypeError: MujocoEnv.__init__() got an unexpected keyword argument 'track_body_id'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 import numpy as np
#       6 # Create environment with camera configuration
# ----> 7 env = gym.make(
#       8     "HalfCheetah-v5",
#       9     render_mode="human",
#      10     camera_id=0,  # Use default camera
#      11     track_body_id=1  # Track the main body of the cheetah (torso)
#      12 )
#      14 # Load your trained model here
#      15 # model = ...
#      17 obs, _ = env.reset()
#
# File d:\projects\Half-Cheetah-RL-Project\rl_proj\lib\site-packages\gymnasium\envs\registration.py:752, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     746         raise error.Error(
#     747             f"You passed render_mode='human' although {env_spec.id} doesn't implement human-rendering natively. "
#     748             "Gym tried to apply the HumanRendering wrapper but it looks like your environment is using the old "
#     749             "rendering API, which is not supported by the HumanRendering wrapper."
#     750         ) from e
#     751     else:
# --> 752         raise type(e)(
#     753             f"{e} was raised from the environment creator for {env_spec.id} with kwargs ({env_spec_kwargs})"
#     754         )
#     756 if not isinstance(env, gym.Env):
#     757     if (
#     758         str(env.__class__.__base__) == "<class 'gym.core.Env'>"
#     759         or str(env.__class__.__base__) == "<class 'gym.core.Wrapper'>"
#     760     ):
#
# TypeError: MujocoEnv.__init__() got an unexpected keyword argument 'track_body_id' was raised from the environment creator for HalfCheetah-v5 with kwargs ({'render_mode': 'human', 'camera_id': 0, 'track_body_id': 1})

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import time
import numpy as np

# Create environment 
env = gym.make("HalfCheetah-v5", render_mode="human")
obs, _ = env.reset()

# Store rewards for plotting
rewards = []

# Run the model
for _ in range(1000):
    action, _states = model.predict(obs)
    obs, reward, done, truncated, info = env.step(action)
    print(reward)
    rewards.append(reward)
    
    # Manually update camera to follow the cheetah
    # Get the cheetah's x position
    cheetah_x_pos = env.unwrapped.data.qpos[0]
    
    # Update the camera's position to follow the cheetah
    if hasattr(env.unwrapped, 'viewer') and env.unwrapped.viewer is not None:
        env.unwrapped.viewer.cam.lookat[0] = cheetah_x_pos
        # You can adjust these values to change the camera angle and distance
        env.unwrapped.viewer.cam.distance = 4.0  # Distance from subject
        env.unwrapped.viewer.cam.elevation = -20.0  # Camera angle
        env.unwrapped.viewer.cam.azimuth = 90.0  # Camera rotation

    if done or truncated:
        obs, _ = env.reset()
    

env.close()

# Plot the rewards
plt.figure(figsize=(10, 6))
plt.plot(rewards)
plt.title("Reward per Step (HalfCheetah)")
plt.xlabel("Timestep")
plt.ylabel("Reward")
plt.grid(True)
plt.show()
# Out:
# -0.1529074722220105
# -0.46699779412078685
# -0.643057637743795
# -0.5811510269213803
# 0.8615578454643906
# 0.6709729604443833
# -1.2988119668525115
# -0.9207855257569066
# 1.1480633683903945
# 1.5614430086718791
# -0.16793841937607457
# -0.6594861778212
# 0.2945556477822118
# 1.955465670040955
# 1.636242312974145
# 0.46473702717624166
# -0.6210187821357074
# 0.6751185651243974
# 2.2144329335868544
# 1.2028420459300686
# 0.03234313491963059
# 0.3780438860713482
# 1.718974860727585
# 2.651658582330749
# 1.5629291755100096
# 0.7507480206598292
# 1.4759726131205033
# 3.1447987632576844
# 2.763150892707741
# 1.1371070558949414
# 1.45562510216865
# 2.5785980693036086
# 3.839643576652822
# 2.6632231881220667
# 0.19918482565384643
# 1.437257101992234
# 3.7820595726252595
# 3.5677799512974797
# 1.917300270103171
# 1.3177977704271662
# 2.1877403577666676
# 3.7568248870831322
# 4.013152447750075
# 2.1848594233193186
# 1.394356746222467
# 2.891520424321703
# 4.54811169788438
# 4.004638264523109
# 2.0662152624341736
# 1.4634622106330681
# 3.965330630350298
# 4.4599299916423725
# 3.4052087376888416
# 1.6003505696320488
# 2.431547882219107
# 4.58749166960634
# 4.680147875501508
# 2.9104256352129063
# 1.3688822809972159
# 2.6199024339110437
# 4.750248386206909
# 3.916665258113781
# 1.9990934411990366
# 0.42270339877194374
# 2.4708154602126626
# 4.1846071638014095
# 3.515991532119614
# 2.052661610755365
# 1.5081788241076133
# 3.421055885285238
# 4.3002225498772795
# 3.5178759185409625
# 2.0305535165199373
# 2.110840591592961
# 3.6961746135334224
# 4.243276372818144
# 2.720001998882651
# 0.9888337761961665
# 1.602490771007858
# 3.4567282417309286
# 3.5691061928187295
# 1.6439770570214733
# 0.5449933816751553
# 2.414557128409399
# 4.058648972112806
# 3.390735096143402
# 1.7667059337943982
# 0.811724204836878
# 2.62910482700228
# 4.089897683779078
# 3.815848899075519
# 2.169336567165132
# 1.3681781553255377
# 3.2056693792126154
# 4.33457169962842
# 3.9977857476889795
# 2.2582629318403917
# 1.9981368934105674
# 4.28272950828196
# 5.072981574366835
# 4.067689438208902
# 2.569828764847138
# 2.130770517150765
# 3.9997235044498822
# 5.082478912083609
# 4.046099008846596
# 1.9368029047840736
# 1.9728073846991165
# 4.55181539782015
# 5.25856054400127
# 3.5178216460913205
# 1.5876176242481534
# 2.4756787313406363
# 3.524294115752568
# 2.692470409322148
# 1.1448347155630003
# 1.1326932583777847
# 2.0338373069050775
# 2.628650810650207
# 1.6937861314542033
# 0.030028339326982234
# 1.2533840961229004
# 3.387975859818411
# 2.3996714140765647
# 0.6823513823479601
# 0.19492652430010082
# 2.5130942361663386
# 3.607570758866416
# 2.2623384550920917
# 1.2165644794964123
# 1.4933162714361004
# 3.5052696805572907
# 3.2618175511331344
# 2.2386844822778045
