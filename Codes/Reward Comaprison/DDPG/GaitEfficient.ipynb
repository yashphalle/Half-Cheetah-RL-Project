# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="gait_optimization_ddpg_training2.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="gait_optimization_ddpg2"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            try:
                # Save the model
                model_path = os.path.join(self.save_dir, 
                                        f"{self.model_prefix}_{self.num_timesteps}")
                self.model.save(model_path)
                print(f"Model saved at {model_path}")
                self.last_save = self.num_timesteps
            except Exception as e:
                print(f"Error saving model at timestep {self.num_timesteps}: {e}")
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class GaitOptimizationCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        # Keep track of previous observations to measure smoothness
        self.prev_obs = None
        
    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.prev_obs = obs
        return obs, info
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.gait_optimization_reward(observation, action, original_reward, info)
        
        # Update previous observation
        self.prev_obs = observation
        
        return observation, modified_reward, terminated, truncated, info
    
    def gait_optimization_reward(self, observation, action, original_reward, info):
        # 1. Original reward component
        original_reward_weight = 1.0
        
        # 2. Movement smoothness component
        # Calculate joint acceleration (change in velocities)
        if self.prev_obs is not None:
            current_velocities = observation[10:17]
            prev_velocities = self.prev_obs[10:17]
            joint_accelerations = np.abs(current_velocities - prev_velocities)
            # Penalize high accelerations (jerky movements)
            smoothness_reward = 0.2 * np.exp(-0.5 * np.mean(joint_accelerations))
        else:
            smoothness_reward = 0
        
        # 3. Energy efficiency through spring-like behavior
        # In biological systems, muscles and tendons store and release energy like springs
        # This term rewards joint movements that follow a spring-like pattern
        joint_angles = observation[2:8]  # All joint angles
        joint_velocities = observation[10:17]  # All joint velocities
        
        # Calculate spring-like behavior score
        # When a joint is extended, it should be moving back (negative velocity)
        # When a joint is flexed, it should be extending (positive velocity)
        # This creates a spring-like oscillation
        spring_score = 0
        for i in range(len(joint_angles)):
            # If joint is extended (positive angle), it should have negative velocity
            # If joint is flexed (negative angle), it should have positive velocity
            # This creates a spring-like oscillation
            spring_like = -1 * joint_angles[i] * joint_velocities[i]
            spring_score += max(0, spring_like)
        
        spring_reward = 0.15 * min(1.0, spring_score / 3.0)
        
        # 4. Gait symmetry reward - encourage alternating leg movements
        # Calculate phase relationships between front and back legs
        if len(joint_velocities) >= 5:
            # Back thigh vs front thigh
            back_thigh_vel = observation[11]
            front_thigh_vel = observation[14]
            # Reward when they're out of phase (one positive, one negative)
            phase_score = back_thigh_vel * front_thigh_vel
            symmetry_reward = 0.1 * np.exp(-2.0 * max(0, phase_score))
        else:
            symmetry_reward = 0
        
        # 5. Power-to-speed efficiency
        forward_reward = info.get("reward_run", 0)
        control_cost = abs(info.get("reward_ctrl", 0))
        
        # If making forward progress, calculate efficiency
        if forward_reward > 0 and control_cost > 0:
            # Higher ratio means more forward movement for energy expended
            efficiency_ratio = forward_reward / (control_cost + 0.1)  # Add 0.1 to avoid division by zero
            efficiency_reward = 0.2 * min(1.0, efficiency_ratio / 10.0)
        else:
            efficiency_reward = 0
                
        # Combined reward
        reward = (original_reward_weight * original_reward + 
                 smoothness_reward + spring_reward + 
                 symmetry_reward + efficiency_reward)
        
        return reward

def train_gait_optimization_with_ddpg():
    try:
        # Setup environment
        print("Creating gait optimization cheetah environment...")
        cheetah_environment = GaitOptimizationCheetahEnv()

        # Action noise for exploration (important for DDPG)
        n_actions = cheetah_environment.action_space.shape[0]
        action_noise = NormalActionNoise(
            mean=np.zeros(n_actions),
            sigma=0.1 * np.ones(n_actions)
        )

        # Initialize DDPG model
        print("Initializing DDPG model...")
        training_model = DDPG(
            policy="MlpPolicy",
            env=cheetah_environment,
            action_noise=action_noise,
            buffer_size=100000,
            learning_rate=1e-3,
            batch_size=256,
            gamma=0.99,
            verbose=1
        )

        # Setup logger with checkpoint saving capability
        print("Setting up training logger...")
        progress_logger = EnhancedTrainingLogger(
            log_filepath="gait_optimization_ddpg_training2.txt",
            save_dir="model_checkpoints", 
            save_freq=50000,
            model_prefix="gait_optimization_ddpg2"
        )

        # Train the model
        print("Starting training for 1,000,000 timesteps...")
        training_model.learn(total_timesteps=1000000, callback=progress_logger)

        # Save the final model
        print("Saving final trained model...")
        training_model.save("gait_optimization_ddpg_final2")

        print("Training completed successfully!")
        print(f"Training logs saved to {progress_logger.log_filepath}")
        print(f"Model checkpoints saved in {progress_logger.save_dir}")
        
    except Exception as e:
        print(f"Training error occurred: {str(e)}")
        print("Training was interrupted, but intermediate models should be saved.")

if __name__ == "__main__":
    train_gait_optimization_with_ddpg()
# Out:
# Creating gait optimization cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...

# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="gait_optimization_ddpg_training3.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="gait_optimization_ddpg3"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            try:
                # Save the model
                model_path = os.path.join(self.save_dir, 
                                        f"{self.model_prefix}_{self.num_timesteps}")
                self.model.save(model_path)
                print(f"Model saved at {model_path}")
                self.last_save = self.num_timesteps
            except Exception as e:
                print(f"Error saving model at timestep {self.num_timesteps}: {e}")
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class GaitOptimizationCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        # Keep track of previous observations to measure smoothness
        self.prev_obs = None
        
    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.prev_obs = obs
        return obs, info
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.gait_optimization_reward(observation, action, original_reward, info)
        
        # Update previous observation
        self.prev_obs = observation
        
        return observation, modified_reward, terminated, truncated, info
    
    def gait_optimization_reward(self, observation, action, original_reward, info):
        # 1. Original reward component
        original_reward_weight = 1.0
        
        # 2. Movement smoothness component
        # Calculate joint acceleration (change in velocities)
        if self.prev_obs is not None:
            current_velocities = observation[10:17]
            prev_velocities = self.prev_obs[10:17]
            joint_accelerations = np.abs(current_velocities - prev_velocities)
            # Penalize high accelerations (jerky movements)
            smoothness_reward = 0.2 * np.exp(-0.5 * np.mean(joint_accelerations))
        else:
            smoothness_reward = 0
        
        # 3. Energy efficiency through spring-like behavior
        # In biological systems, muscles and tendons store and release energy like springs
        # This term rewards joint movements that follow a spring-like pattern
        joint_angles = observation[2:8]  # All joint angles
        joint_velocities = observation[10:17]  # All joint velocities
        
        # Calculate spring-like behavior score
        # When a joint is extended, it should be moving back (negative velocity)
        # When a joint is flexed, it should be extending (positive velocity)
        # This creates a spring-like oscillation
        spring_score = 0
        for i in range(len(joint_angles)):
            # If joint is extended (positive angle), it should have negative velocity
            # If joint is flexed (negative angle), it should have positive velocity
            # This creates a spring-like oscillation
            spring_like = -1 * joint_angles[i] * joint_velocities[i]
            spring_score += max(0, spring_like)
        
        spring_reward = 0.15 * min(1.0, spring_score / 3.0)
        
        # 4. Gait symmetry reward - encourage alternating leg movements
        # Calculate phase relationships between front and back legs
        if len(joint_velocities) >= 5:
            # Back thigh vs front thigh
            back_thigh_vel = observation[11]
            front_thigh_vel = observation[14]
            # Reward when they're out of phase (one positive, one negative)
            phase_score = back_thigh_vel * front_thigh_vel
            symmetry_reward = 0.1 * np.exp(-2.0 * max(0, phase_score))
        else:
            symmetry_reward = 0
        
        # 5. Power-to-speed efficiency
        forward_reward = info.get("reward_run", 0)
        control_cost = abs(info.get("reward_ctrl", 0))
        
        # If making forward progress, calculate efficiency
        if forward_reward > 0 and control_cost > 0:
            # Higher ratio means more forward movement for energy expended
            efficiency_ratio = forward_reward / (control_cost + 0.1)  # Add 0.1 to avoid division by zero
            efficiency_reward = 0.2 * min(1.0, efficiency_ratio / 10.0)
        else:
            efficiency_reward = 0
                
        # Combined reward
        reward = (original_reward_weight * original_reward + 
                 smoothness_reward + spring_reward + 
                 symmetry_reward + efficiency_reward)
        
        return reward

def train_gait_optimization_with_ddpg():
    try:
        # Setup environment
        print("Creating gait optimization cheetah environment...")
        cheetah_environment = GaitOptimizationCheetahEnv()

        # Action noise for exploration (important for DDPG)
        n_actions = cheetah_environment.action_space.shape[0]
        action_noise = NormalActionNoise(
            mean=np.zeros(n_actions),
            sigma=0.1 * np.ones(n_actions)
        )

        # Initialize DDPG model
        print("Initializing DDPG model...")
        training_model = DDPG(
            policy="MlpPolicy",
            env=cheetah_environment,
            action_noise=action_noise,
            buffer_size=100000,
            learning_rate=1e-3,
            batch_size=256,
            gamma=0.99,
            verbose=1
        )

        # Setup logger with checkpoint saving capability
        print("Setting up training logger...")
        progress_logger = EnhancedTrainingLogger(
            log_filepath="gait_optimization_ddpg_training3.txt",
            save_dir="model_checkpoints", 
            save_freq=50000,
            model_prefix="gait_optimization_ddpg3"
        )

        # Train the model
        print("Starting training for 1,000,000 timesteps...")
        training_model.learn(total_timesteps=1000000, callback=progress_logger)

        # Save the final model
        print("Saving final trained model...")
        training_model.save("gait_optimization_ddpg_final3")

        print("Training completed successfully!")
        print(f"Training logs saved to {progress_logger.log_filepath}")
        print(f"Model checkpoints saved in {progress_logger.save_dir}")
        
    except Exception as e:
        print(f"Training error occurred: {str(e)}")
        print("Training was interrupted, but intermediate models should be saved.")

if __name__ == "__main__":
    train_gait_optimization_with_ddpg()
# Out:
# Creating gait optimization cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -238     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 96       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -3.58    |
# |    critic_loss     | 0.183    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -164     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 94       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 0.873    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 94       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -25.2    |
# |    critic_loss     | 0.746    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -89.4    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 94       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 1.41     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -44.2    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 94       |
# |    time_elapsed    | 212      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -54.2    |
# |    critic_loss     | 2.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 99       |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 94       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 2.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 357      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 297      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 2.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 590      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 94       |
# |    time_elapsed    | 340      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 5.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 878      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 94       |
# |    time_elapsed    | 382      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 6.45     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.09e+03 |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 93       |
# |    time_elapsed    | 425      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -214     |
# |    critic_loss     | 9.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.25e+03 |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 93       |
# |    time_elapsed    | 468      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -248     |
# |    critic_loss     | 9.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.42e+03 |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 93       |
# |    time_elapsed    | 510      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -283     |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_50000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.56e+03 |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 93       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.66e+03 |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 93       |
# |    time_elapsed    | 596      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -340     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.7e+03  |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 93       |
# |    time_elapsed    | 639      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -356     |
# |    critic_loss     | 15.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.79e+03 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 93       |
# |    time_elapsed    | 681      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -379     |
# |    critic_loss     | 18       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.89e+03 |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 93       |
# |    time_elapsed    | 724      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.97e+03 |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 93       |
# |    time_elapsed    | 767      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.06e+03 |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 93       |
# |    time_elapsed    | 809      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 13       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 93       |
# |    time_elapsed    | 851      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -436     |
# |    critic_loss     | 16.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.02e+03 |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 93       |
# |    time_elapsed    | 894      |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -450     |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 93       |
# |    time_elapsed    | 937      |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -449     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.02e+03 |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 93       |
# |    time_elapsed    | 980      |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.08e+03 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 93       |
# |    time_elapsed    | 1022     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -444     |
# |    critic_loss     | 20.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95899    |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.1e+03  |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 93       |
# |    time_elapsed    | 1065     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 18.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.25e+03 |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 93       |
# |    time_elapsed    | 1108     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -442     |
# |    critic_loss     | 19.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.4e+03  |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 93       |
# |    time_elapsed    | 1151     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -445     |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 93       |
# |    time_elapsed    | 1194     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -438     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 93       |
# |    time_elapsed    | 1237     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 16.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.83e+03 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 93       |
# |    time_elapsed    | 1280     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -444     |
# |    critic_loss     | 21.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.94e+03 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 93       |
# |    time_elapsed    | 1324     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -446     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.01e+03 |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 93       |
# |    time_elapsed    | 1367     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -444     |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.07e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 93       |
# |    time_elapsed    | 1410     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -442     |
# |    critic_loss     | 11.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.09e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 93       |
# |    time_elapsed    | 1453     |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -437     |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.11e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 93       |
# |    time_elapsed    | 1496     |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -437     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.14e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 93       |
# |    time_elapsed    | 1538     |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -435     |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.15e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 93       |
# |    time_elapsed    | 1581     |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -431     |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_150000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.16e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 93       |
# |    time_elapsed    | 1624     |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -427     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.19e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 93       |
# |    time_elapsed    | 1667     |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -430     |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 93       |
# |    time_elapsed    | 1709     |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -430     |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.27e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 93       |
# |    time_elapsed    | 1752     |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -425     |
# |    critic_loss     | 16       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 93       |
# |    time_elapsed    | 1795     |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -425     |
# |    critic_loss     | 12.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.3e+03  |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 93       |
# |    time_elapsed    | 1838     |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -428     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.3e+03  |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 93       |
# |    time_elapsed    | 1880     |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -436     |
# |    critic_loss     | 12.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 93       |
# |    time_elapsed    | 1922     |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -432     |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.47e+03 |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 93       |
# |    time_elapsed    | 1965     |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -438     |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.56e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 93       |
# |    time_elapsed    | 2008     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -443     |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.6e+03  |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 93       |
# |    time_elapsed    | 2050     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -446     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.61e+03 |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 93       |
# |    time_elapsed    | 2093     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -442     |
# |    critic_loss     | 12.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_200000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.66e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 93       |
# |    time_elapsed    | 2136     |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -444     |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.67e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 93       |
# |    time_elapsed    | 2178     |
# |    total_timesteps | 204000   |
# | train/             |          |
# |    actor_loss      | -442     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.67e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 93       |
# |    time_elapsed    | 2221     |
# |    total_timesteps | 208000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 11.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 93       |
# |    time_elapsed    | 2264     |
# |    total_timesteps | 212000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 11.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 211899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 93       |
# |    time_elapsed    | 2307     |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | -439     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 93       |
# |    time_elapsed    | 2350     |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | -439     |
# |    critic_loss     | 13.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 93       |
# |    time_elapsed    | 2392     |
# |    total_timesteps | 224000   |
# | train/             |          |
# |    actor_loss      | -442     |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 93       |
# |    time_elapsed    | 2435     |
# |    total_timesteps | 228000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 10.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 227899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.69e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 93       |
# |    time_elapsed    | 2478     |
# |    total_timesteps | 232000   |
# | train/             |          |
# |    actor_loss      | -441     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 231899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.69e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 93       |
# |    time_elapsed    | 2520     |
# |    total_timesteps | 236000   |
# | train/             |          |
# |    actor_loss      | -439     |
# |    critic_loss     | 9.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 235899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.7e+03  |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 93       |
# |    time_elapsed    | 2563     |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | -440     |
# |    critic_loss     | 10.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 93       |
# |    time_elapsed    | 2606     |
# |    total_timesteps | 244000   |
# | train/             |          |
# |    actor_loss      | -438     |
# |    critic_loss     | 14.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 243899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 93       |
# |    time_elapsed    | 2648     |
# |    total_timesteps | 248000   |
# | train/             |          |
# |    actor_loss      | -439     |
# |    critic_loss     | 9.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 247899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_250000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.7e+03  |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 93       |
# |    time_elapsed    | 2691     |
# |    total_timesteps | 252000   |
# | train/             |          |
# |    actor_loss      | -438     |
# |    critic_loss     | 20.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 251899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.6e+03  |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 93       |
# |    time_elapsed    | 2734     |
# |    total_timesteps | 256000   |
# | train/             |          |
# |    actor_loss      | -405     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.52e+03 |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 93       |
# |    time_elapsed    | 2776     |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | -387     |
# |    critic_loss     | 10.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 259899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.49e+03 |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 93       |
# |    time_elapsed    | 2819     |
# |    total_timesteps | 264000   |
# | train/             |          |
# |    actor_loss      | -382     |
# |    critic_loss     | 11.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 263899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.49e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 93       |
# |    time_elapsed    | 2862     |
# |    total_timesteps | 268000   |
# | train/             |          |
# |    actor_loss      | -391     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.48e+03 |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 93       |
# |    time_elapsed    | 2905     |
# |    total_timesteps | 272000   |
# | train/             |          |
# |    actor_loss      | -397     |
# |    critic_loss     | 16.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 271899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.48e+03 |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 93       |
# |    time_elapsed    | 2948     |
# |    total_timesteps | 276000   |
# | train/             |          |
# |    actor_loss      | -404     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 275899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.48e+03 |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 93       |
# |    time_elapsed    | 2991     |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | -407     |
# |    critic_loss     | 10.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 93       |
# |    time_elapsed    | 3033     |
# |    total_timesteps | 284000   |
# | train/             |          |
# |    actor_loss      | -409     |
# |    critic_loss     | 18.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 93       |
# |    time_elapsed    | 3076     |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -412     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 93       |
# |    time_elapsed    | 3119     |
# |    total_timesteps | 292000   |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 23.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 291899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 93       |
# |    time_elapsed    | 3162     |
# |    total_timesteps | 296000   |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_300000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 93       |
# |    time_elapsed    | 3205     |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -417     |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 93       |
# |    time_elapsed    | 3247     |
# |    total_timesteps | 304000   |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 12.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 303899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 93       |
# |    time_elapsed    | 3290     |
# |    total_timesteps | 308000   |
# | train/             |          |
# |    actor_loss      | -417     |
# |    critic_loss     | 9.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 307899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 93       |
# |    time_elapsed    | 3333     |
# |    total_timesteps | 312000   |
# | train/             |          |
# |    actor_loss      | -414     |
# |    critic_loss     | 15.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 311899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 93       |
# |    time_elapsed    | 3376     |
# |    total_timesteps | 316000   |
# | train/             |          |
# |    actor_loss      | -420     |
# |    critic_loss     | 13.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 315899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 93       |
# |    time_elapsed    | 3419     |
# |    total_timesteps | 320000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 13       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 319899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 93       |
# |    time_elapsed    | 3462     |
# |    total_timesteps | 324000   |
# | train/             |          |
# |    actor_loss      | -419     |
# |    critic_loss     | 18.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 323899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 93       |
# |    time_elapsed    | 3505     |
# |    total_timesteps | 328000   |
# | train/             |          |
# |    actor_loss      | -420     |
# |    critic_loss     | 18.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 327899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 93       |
# |    time_elapsed    | 3547     |
# |    total_timesteps | 332000   |
# | train/             |          |
# |    actor_loss      | -423     |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 331899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.44e+03 |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 93       |
# |    time_elapsed    | 3590     |
# |    total_timesteps | 336000   |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 18.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 335899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 93       |
# |    time_elapsed    | 3633     |
# |    total_timesteps | 340000   |
# | train/             |          |
# |    actor_loss      | -419     |
# |    critic_loss     | 19       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.42e+03 |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 93       |
# |    time_elapsed    | 3675     |
# |    total_timesteps | 344000   |
# | train/             |          |
# |    actor_loss      | -419     |
# |    critic_loss     | 14.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 343899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 93       |
# |    time_elapsed    | 3717     |
# |    total_timesteps | 348000   |
# | train/             |          |
# |    actor_loss      | -420     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 347899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_350000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 93       |
# |    time_elapsed    | 3760     |
# |    total_timesteps | 352000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 16.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 351899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.52e+03 |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 93       |
# |    time_elapsed    | 3802     |
# |    total_timesteps | 356000   |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 355899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.6e+03  |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 93       |
# |    time_elapsed    | 3844     |
# |    total_timesteps | 360000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 16.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 359899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.62e+03 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 93       |
# |    time_elapsed    | 3886     |
# |    total_timesteps | 364000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 363899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.62e+03 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 93       |
# |    time_elapsed    | 3929     |
# |    total_timesteps | 368000   |
# | train/             |          |
# |    actor_loss      | -422     |
# |    critic_loss     | 9.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 367899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.63e+03 |
# ...
# |    fps             | 94       |
# |    time_elapsed    | 9340     |
# |    total_timesteps | 880000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 879899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.72e+03 |
# | time/              |          |
# |    episodes        | 884      |
# |    fps             | 94       |
# |    time_elapsed    | 9382     |
# |    total_timesteps | 884000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 883899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.72e+03 |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 94       |
# |    time_elapsed    | 9425     |
# |    total_timesteps | 888000   |
# | train/             |          |
# |    actor_loss      | -418     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 887899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 94       |
# |    time_elapsed    | 9467     |
# |    total_timesteps | 892000   |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 891899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 94       |
# |    time_elapsed    | 9509     |
# |    total_timesteps | 896000   |
# | train/             |          |
# |    actor_loss      | -413     |
# |    critic_loss     | 20.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 895899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_900000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 94       |
# |    time_elapsed    | 9552     |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 13.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 899899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.7e+03  |
# | time/              |          |
# |    episodes        | 904      |
# |    fps             | 94       |
# |    time_elapsed    | 9594     |
# |    total_timesteps | 904000   |
# | train/             |          |
# |    actor_loss      | -417     |
# |    critic_loss     | 7.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 903899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.69e+03 |
# | time/              |          |
# |    episodes        | 908      |
# |    fps             | 94       |
# |    time_elapsed    | 9637     |
# |    total_timesteps | 908000   |
# | train/             |          |
# |    actor_loss      | -414     |
# |    critic_loss     | 18.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 907899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 912      |
# |    fps             | 94       |
# |    time_elapsed    | 9679     |
# |    total_timesteps | 912000   |
# | train/             |          |
# |    actor_loss      | -415     |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 911899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.68e+03 |
# | time/              |          |
# |    episodes        | 916      |
# |    fps             | 94       |
# |    time_elapsed    | 9722     |
# |    total_timesteps | 916000   |
# | train/             |          |
# |    actor_loss      | -416     |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 915899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.66e+03 |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 94       |
# |    time_elapsed    | 9764     |
# |    total_timesteps | 920000   |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 12.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 919899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.66e+03 |
# | time/              |          |
# |    episodes        | 924      |
# |    fps             | 94       |
# |    time_elapsed    | 9807     |
# |    total_timesteps | 924000   |
# | train/             |          |
# |    actor_loss      | -410     |
# |    critic_loss     | 16.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 923899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.66e+03 |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 94       |
# |    time_elapsed    | 9850     |
# |    total_timesteps | 928000   |
# | train/             |          |
# |    actor_loss      | -412     |
# |    critic_loss     | 13.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 927899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 94       |
# |    time_elapsed    | 9892     |
# |    total_timesteps | 932000   |
# | train/             |          |
# |    actor_loss      | -410     |
# |    critic_loss     | 15.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 931899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 94       |
# |    time_elapsed    | 9935     |
# |    total_timesteps | 936000   |
# | train/             |          |
# |    actor_loss      | -408     |
# |    critic_loss     | 9.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 935899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 94       |
# |    time_elapsed    | 9977     |
# |    total_timesteps | 940000   |
# | train/             |          |
# |    actor_loss      | -406     |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 939899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 94       |
# |    time_elapsed    | 10020    |
# |    total_timesteps | 944000   |
# | train/             |          |
# |    actor_loss      | -409     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 943899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.64e+03 |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 94       |
# |    time_elapsed    | 10062    |
# |    total_timesteps | 948000   |
# | train/             |          |
# |    actor_loss      | -409     |
# |    critic_loss     | 8.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 947899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_950000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.64e+03 |
# | time/              |          |
# |    episodes        | 952      |
# |    fps             | 94       |
# |    time_elapsed    | 10104    |
# |    total_timesteps | 952000   |
# | train/             |          |
# |    actor_loss      | -408     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 951899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.64e+03 |
# | time/              |          |
# |    episodes        | 956      |
# |    fps             | 94       |
# |    time_elapsed    | 10147    |
# |    total_timesteps | 956000   |
# | train/             |          |
# |    actor_loss      | -407     |
# |    critic_loss     | 14.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 955899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.63e+03 |
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 94       |
# |    time_elapsed    | 10189    |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | -406     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 959899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.63e+03 |
# | time/              |          |
# |    episodes        | 964      |
# |    fps             | 94       |
# |    time_elapsed    | 10231    |
# |    total_timesteps | 964000   |
# | train/             |          |
# |    actor_loss      | -410     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 963899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.63e+03 |
# | time/              |          |
# |    episodes        | 968      |
# |    fps             | 94       |
# |    time_elapsed    | 10274    |
# |    total_timesteps | 968000   |
# | train/             |          |
# |    actor_loss      | -406     |
# |    critic_loss     | 25.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 967899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.61e+03 |
# | time/              |          |
# |    episodes        | 972      |
# |    fps             | 94       |
# |    time_elapsed    | 10317    |
# |    total_timesteps | 972000   |
# | train/             |          |
# |    actor_loss      | -399     |
# |    critic_loss     | 27       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 971899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.59e+03 |
# | time/              |          |
# |    episodes        | 976      |
# |    fps             | 94       |
# |    time_elapsed    | 10359    |
# |    total_timesteps | 976000   |
# | train/             |          |
# |    actor_loss      | -392     |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 975899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.57e+03 |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 94       |
# |    time_elapsed    | 10402    |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | -387     |
# |    critic_loss     | 16.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 979899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.56e+03 |
# | time/              |          |
# |    episodes        | 984      |
# |    fps             | 94       |
# |    time_elapsed    | 10445    |
# |    total_timesteps | 984000   |
# | train/             |          |
# |    actor_loss      | -384     |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 983899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.54e+03 |
# | time/              |          |
# |    episodes        | 988      |
# |    fps             | 94       |
# |    time_elapsed    | 10487    |
# |    total_timesteps | 988000   |
# | train/             |          |
# |    actor_loss      | -381     |
# |    critic_loss     | 14.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 987899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.53e+03 |
# | time/              |          |
# |    episodes        | 992      |
# |    fps             | 94       |
# |    time_elapsed    | 10530    |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | -377     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 991899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.51e+03 |
# | time/              |          |
# |    episodes        | 996      |
# |    fps             | 94       |
# |    time_elapsed    | 10571    |
# |    total_timesteps | 996000   |
# | train/             |          |
# |    actor_loss      | -374     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 995899   |
# ---------------------------------
# Model saved at model_checkpoints/gait_optimization_ddpg3_1000000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.49e+03 |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 94       |
# |    time_elapsed    | 10606    |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | -372     |
# |    critic_loss     | 15.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999899   |
# ---------------------------------
# Saving final trained model...
# Training completed successfully!
# Training logs saved to gait_optimization_ddpg_training3.txt
# Model checkpoints saved in model_checkpoints
