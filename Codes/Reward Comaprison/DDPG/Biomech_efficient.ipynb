# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="efficient_cheetah_ddpg_training2.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="efficient_cheetah_ddpg2"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            try:
                # Save the model
                model_path = os.path.join(self.save_dir, 
                                        f"{self.model_prefix}_{self.num_timesteps}")
                self.model.save(model_path)
                print(f"Model saved at {model_path}")
                self.last_save = self.num_timesteps
            except Exception as e:
                print(f"Error saving model at timestep {self.num_timesteps}: {e}")
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class EfficientCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.ideal_reward_function(observation, action, original_reward, info)
        return observation, modified_reward, terminated, truncated, info
    
    def ideal_reward_function(self, observation, action, original_reward, info):
        # 1. Maintain core elements of original reward (forward progress minus control costs)
        original_reward_weight = 1.0
        
        # 2. Efficient torso orientation - true torso angle from observation[1]
        torso_angle = observation[1]  # rooty - actual torso orientation
        # Slightly forward-leaning posture (about 0.2 rad) is efficient for running
        posture_reward = 0.3 * np.exp(-5 * (torso_angle - 0.2)**2)
        
        # 3. Coordinated leg movement - emulate galloping gait
        # Synchronize front and back leg patterns
        back_thigh_vel = observation[11]  # Angular velocity of back thigh
        front_thigh_vel = observation[14]  # Angular velocity of front thigh
        # Reward opposite movement (galloping pattern)
        gait_reward = 0.2 * np.exp(-2 * (back_thigh_vel + front_thigh_vel)**2)
        
        # 4. Energy efficiency - discourage wasteful actions
        # Penalize large action magnitudes while still allowing powerful movements when needed
        energy_efficiency = 0.1 * (1.0 - min(1.0, np.mean(np.abs(action))))
        
        # 5. Anti-inversion component - prevent flipping
        # Penalize when torso starts to flip upside down
        anti_inversion = -0.5 * min(0, np.cos(torso_angle))
        
        # 6. Foot ground contact reward - efficient push-off
        back_foot_angle = observation[4]   # bfoot angle
        front_foot_angle = observation[7]  # ffoot angle
        # Reward proper foot positioning for push-off
        stance_reward = 0.1 * (np.cos(back_foot_angle) + np.cos(front_foot_angle))
        
        # Combined reward
        reward = (posture_reward + gait_reward + energy_efficiency + 
                  anti_inversion + stance_reward + 
                  original_reward_weight * original_reward)
        
        return reward

def train_efficient_cheetah_with_ddpg():
    try:
        # Setup environment
        print("Creating efficient cheetah environment...")
        cheetah_environment = EfficientCheetahEnv()

        # Action noise for exploration (important for DDPG)
        n_actions = cheetah_environment.action_space.shape[0]
        action_noise = NormalActionNoise(
            mean=np.zeros(n_actions),
            sigma=0.1 * np.ones(n_actions)
        )

        # Initialize DDPG model
        print("Initializing DDPG model...")
        training_model = DDPG(
            policy="MlpPolicy",
            env=cheetah_environment,
            action_noise=action_noise,
            buffer_size=100000,
            learning_rate=1e-3,
            batch_size=256,
            gamma=0.99,
            verbose=1
        )

        # Setup logger with checkpoint saving capability
        print("Setting up training logger...")
        progress_logger = EnhancedTrainingLogger(
            log_filepath="efficient_cheetah_ddpg_training2.txt",
            save_dir="model_checkpoints",
            save_freq=50000,
            model_prefix="efficient_cheetah_ddpg2"
        )

        # Train the model
        print("Starting training for 1,000,000 timesteps...")
        training_model.learn(total_timesteps=1000000, callback=progress_logger)

        # Save the final model
        print("Saving final trained model...")
        training_model.save("efficient_cheetah_ddpg_final2")

        print("Training completed successfully!")
        print(f"Training logs saved to {progress_logger.log_filepath}")
        print(f"Model checkpoints saved in {progress_logger.save_dir}")
        
    except Exception as e:
        print(f"Training error occurred: {str(e)}")
        print("Training was interrupted, but intermediate models should be saved.")

if __name__ == "__main__":
    train_efficient_cheetah_with_ddpg()
# Out:
# Creating efficient cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -7.03    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 13       |
# |    time_elapsed    | 292      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -6.18    |
# |    critic_loss     | 0.0695   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -3.71    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 13       |
# |    time_elapsed    | 590      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -8.57    |
# |    critic_loss     | 0.099    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 20.8     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 13       |
# |    time_elapsed    | 891      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -8.63    |
# |    critic_loss     | 0.0105   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 16.3     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 13       |
# |    time_elapsed    | 1194     |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -8.88    |
# |    critic_loss     | 0.0138   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 11       |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 13       |
# |    time_elapsed    | 1497     |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -7.52    |
# |    critic_loss     | 0.0088   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 13       |
# |    time_elapsed    | 1799     |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.177    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 29.1     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 13       |
# |    time_elapsed    | 2100     |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -39.5    |
# |    critic_loss     | 0.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 71.9     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 13       |
# |    time_elapsed    | 2402     |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -61.8    |
# |    critic_loss     | 0.549    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 13       |
# |    time_elapsed    | 2703     |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -78.1    |
# |    critic_loss     | 0.874    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 13       |
# |    time_elapsed    | 3005     |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 2.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 13       |
# |    time_elapsed    | 3305     |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 13       |
# |    time_elapsed    | 3603     |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 2.41     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_50000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 13       |
# |    time_elapsed    | 3901     |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 2.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 13       |
# |    time_elapsed    | 4198     |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 1.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 314      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 13       |
# |    time_elapsed    | 4498     |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 2.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 379      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 13       |
# |    time_elapsed    | 4795     |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -143     |
# |    critic_loss     | 2.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 438      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 13       |
# |    time_elapsed    | 5093     |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -153     |
# |    critic_loss     | 3.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 484      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 13       |
# |    time_elapsed    | 5393     |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -162     |
# |    critic_loss     | 3.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 537      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 13       |
# |    time_elapsed    | 5691     |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -176     |
# |    critic_loss     | 4.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 615      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 13       |
# |    time_elapsed    | 5989     |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -191     |
# |    critic_loss     | 6.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 699      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 13       |
# |    time_elapsed    | 6288     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -197     |
# |    critic_loss     | 5.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 802      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 13       |
# |    time_elapsed    | 6586     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 7.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 885      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 13       |
# |    time_elapsed    | 6884     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 7.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 959      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 13       |
# |    time_elapsed    | 7183     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -234     |
# |    critic_loss     | 6.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95899    |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.03e+03 |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 13       |
# |    time_elapsed    | 7481     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -251     |
# |    critic_loss     | 9.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 13       |
# |    time_elapsed    | 7779     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -268     |
# |    critic_loss     | 6.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.3e+03  |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 13       |
# |    time_elapsed    | 8078     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.43e+03 |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 13       |
# |    time_elapsed    | 8378     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -303     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.57e+03 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 13       |
# |    time_elapsed    | 8677     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 12       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.72e+03 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 13       |
# |    time_elapsed    | 8978     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 12.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 13       |
# |    time_elapsed    | 9278     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 14.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 13       |
# |    time_elapsed    | 9578     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.12e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 13       |
# |    time_elapsed    | 9877     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -382     |
# |    critic_loss     | 19.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.27e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 13       |
# |    time_elapsed    | 10177    |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -391     |
# |    critic_loss     | 15.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.42e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 13       |
# |    time_elapsed    | 10477    |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -403     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.56e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 13       |
# |    time_elapsed    | 10775    |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -424     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.74e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 13       |
# |    time_elapsed    | 11074    |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -433     |
# |    critic_loss     | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_150000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.91e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 13       |
# |    time_elapsed    | 11375    |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -455     |
# |    critic_loss     | 18       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.08e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 13       |
# |    time_elapsed    | 11675    |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -474     |
# |    critic_loss     | 18.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 13       |
# |    time_elapsed    | 11977    |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -503     |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 13       |
# |    time_elapsed    | 12277    |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -515     |
# |    critic_loss     | 11.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.57e+03 |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 13       |
# |    time_elapsed    | 12579    |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -543     |
# |    critic_loss     | 17.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.71e+03 |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 13       |
# |    time_elapsed    | 12881    |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -559     |
# |    critic_loss     | 19.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.89e+03 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 13       |
# |    time_elapsed    | 13185    |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -572     |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.05e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 13       |
# |    time_elapsed    | 13486    |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -600     |
# |    critic_loss     | 20.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.2e+03  |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 13       |
# |    time_elapsed    | 13786    |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -608     |
# |    critic_loss     | 14.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.33e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 13       |
# |    time_elapsed    | 14087    |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -620     |
# |    critic_loss     | 17.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.48e+03 |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 13       |
# |    time_elapsed    | 14388    |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -644     |
# |    critic_loss     | 30.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.63e+03 |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 13       |
# |    time_elapsed    | 14688    |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -654     |
# |    critic_loss     | 28.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_200000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.8e+03  |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 13       |
# |    time_elapsed    | 14991    |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -674     |
# |    critic_loss     | 21.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.94e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 13       |
# |    time_elapsed    | 15291    |
# |    total_timesteps | 204000   |
# | train/             |          |
# |    actor_loss      | -689     |
# |    critic_loss     | 18.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.08e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 13       |
# |    time_elapsed    | 15594    |
# |    total_timesteps | 208000   |
# | train/             |          |
# |    actor_loss      | -708     |
# |    critic_loss     | 18.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.24e+03 |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 13       |
# |    time_elapsed    | 15896    |
# |    total_timesteps | 212000   |
# | train/             |          |
# |    actor_loss      | -726     |
# |    critic_loss     | 33.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 211899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.38e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 13       |
# |    time_elapsed    | 16199    |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | -743     |
# |    critic_loss     | 20.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.54e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 13       |
# |    time_elapsed    | 16503    |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | -758     |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.69e+03 |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 13       |
# |    time_elapsed    | 16809    |
# |    total_timesteps | 224000   |
# | train/             |          |
# |    actor_loss      | -771     |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.85e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 13       |
# |    time_elapsed    | 17116    |
# |    total_timesteps | 228000   |
# | train/             |          |
# |    actor_loss      | -791     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 227899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.03e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 13       |
# |    time_elapsed    | 17423    |
# |    total_timesteps | 232000   |
# | train/             |          |
# |    actor_loss      | -811     |
# |    critic_loss     | 17.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 231899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.18e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 13       |
# |    time_elapsed    | 17730    |
# |    total_timesteps | 236000   |
# | train/             |          |
# |    actor_loss      | -832     |
# |    critic_loss     | 21.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 235899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.32e+03 |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 13       |
# |    time_elapsed    | 18039    |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | -841     |
# |    critic_loss     | 16.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.47e+03 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 13       |
# |    time_elapsed    | 18347    |
# |    total_timesteps | 244000   |
# | train/             |          |
# |    actor_loss      | -860     |
# |    critic_loss     | 24.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 243899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.6e+03  |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 13       |
# |    time_elapsed    | 18652    |
# |    total_timesteps | 248000   |
# | train/             |          |
# |    actor_loss      | -876     |
# |    critic_loss     | 22       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 247899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_250000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.73e+03 |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 13       |
# |    time_elapsed    | 18960    |
# |    total_timesteps | 252000   |
# | train/             |          |
# |    actor_loss      | -885     |
# |    critic_loss     | 41.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 251899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 6.86e+03 |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 13       |
# |    time_elapsed    | 19267    |
# |    total_timesteps | 256000   |
# | train/             |          |
# |    actor_loss      | -910     |
# |    critic_loss     | 21.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7e+03    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 13       |
# |    time_elapsed    | 19574    |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | -917     |
# |    critic_loss     | 19.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 259899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.05e+03 |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 13       |
# |    time_elapsed    | 19882    |
# |    total_timesteps | 264000   |
# | train/             |          |
# |    actor_loss      | -933     |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 263899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.13e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 13       |
# |    time_elapsed    | 20191    |
# |    total_timesteps | 268000   |
# | train/             |          |
# |    actor_loss      | -946     |
# |    critic_loss     | 35.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.2e+03  |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 13       |
# |    time_elapsed    | 20499    |
# |    total_timesteps | 272000   |
# | train/             |          |
# |    actor_loss      | -958     |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 271899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.24e+03 |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 13       |
# |    time_elapsed    | 20808    |
# |    total_timesteps | 276000   |
# | train/             |          |
# |    actor_loss      | -973     |
# |    critic_loss     | 31.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 275899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.34e+03 |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 13       |
# |    time_elapsed    | 21115    |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | -976     |
# |    critic_loss     | 26.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.45e+03 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 13       |
# |    time_elapsed    | 21422    |
# |    total_timesteps | 284000   |
# | train/             |          |
# |    actor_loss      | -996     |
# |    critic_loss     | 26.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 7.56e+03 |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 13       |
# |    time_elapsed    | 21730    |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -988     |
# |    critic_loss     | 34.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 7.61e+03  |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 13        |
# |    time_elapsed    | 22037     |
# |    total_timesteps | 292000    |
# | train/             |           |
# |    actor_loss      | -1.02e+03 |
# |    critic_loss     | 33.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 291899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 7.71e+03  |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 13        |
# |    time_elapsed    | 22343     |
# |    total_timesteps | 296000    |
# | train/             |           |
# |    actor_loss      | -1.03e+03 |
# |    critic_loss     | 36.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 295899    |
# ----------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg2_300000
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 7.8e+03   |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 13        |
# |    time_elapsed    | 22650     |
# |    total_timesteps | 300000    |
# | train/             |           |
# |    actor_loss      | -1.02e+03 |
# |    critic_loss     | 27.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 299899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 7.9e+03   |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 13        |
# |    time_elapsed    | 22956     |
# |    total_timesteps | 304000    |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 34.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 303899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 7.98e+03  |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 13        |
# |    time_elapsed    | 23264     |
# |    total_timesteps | 308000    |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 31.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 307899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.07e+03  |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 13        |
# |    time_elapsed    | 23571     |
# |    total_timesteps | 312000    |
# | train/             |           |
# |    actor_loss      | -1.06e+03 |
# |    critic_loss     | 30.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 311899    |
# ----------------------------------

# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="efficient_cheetah_ddpg_training3.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="efficient_cheetah_ddpg3"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            try:
                # Save the model
                model_path = os.path.join(self.save_dir, 
                                        f"{self.model_prefix}_{self.num_timesteps}")
                self.model.save(model_path)
                print(f"Model saved at {model_path}")
                self.last_save = self.num_timesteps
            except Exception as e:
                print(f"Error saving model at timestep {self.num_timesteps}: {e}")
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class EfficientCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.ideal_reward_function(observation, action, original_reward, info)
        return observation, modified_reward, terminated, truncated, info
    
    def ideal_reward_function(self, observation, action, original_reward, info):
        # 1. Maintain core elements of original reward (forward progress minus control costs)
        original_reward_weight = 1.0
        
        # 2. Efficient torso orientation - true torso angle from observation[1]
        torso_angle = observation[1]  # rooty - actual torso orientation
        # Slightly forward-leaning posture (about 0.2 rad) is efficient for running
        posture_reward = 0.3 * np.exp(-5 * (torso_angle - 0.2)**2)
        
        # 3. Coordinated leg movement - emulate galloping gait
        # Synchronize front and back leg patterns
        back_thigh_vel = observation[11]  # Angular velocity of back thigh
        front_thigh_vel = observation[14]  # Angular velocity of front thigh
        # Reward opposite movement (galloping pattern)
        gait_reward = 0.2 * np.exp(-2 * (back_thigh_vel + front_thigh_vel)**2)
        
        # 4. Energy efficiency - discourage wasteful actions
        # Penalize large action magnitudes while still allowing powerful movements when needed
        energy_efficiency = 0.1 * (1.0 - min(1.0, np.mean(np.abs(action))))
        
        # 5. Anti-inversion component - prevent flipping
        # Penalize when torso starts to flip upside down
        anti_inversion = -0.5 * min(0, np.cos(torso_angle))
        
        # 6. Foot ground contact reward - efficient push-off
        back_foot_angle = observation[4]   # bfoot angle
        front_foot_angle = observation[7]  # ffoot angle
        # Reward proper foot positioning for push-off
        stance_reward = 0.1 * (np.cos(back_foot_angle) + np.cos(front_foot_angle))
        
        # Combined reward
        reward = (posture_reward + gait_reward + energy_efficiency + 
                  anti_inversion + stance_reward + 
                  original_reward_weight * original_reward)
        
        return reward

def train_efficient_cheetah_with_ddpg():
    try:
        # Setup environment
        print("Creating efficient cheetah environment...")
        cheetah_environment = EfficientCheetahEnv()

        # Action noise for exploration (important for DDPG)
        n_actions = cheetah_environment.action_space.shape[0]
        action_noise = NormalActionNoise(
            mean=np.zeros(n_actions),
            sigma=0.1 * np.ones(n_actions)
        )

        # Initialize DDPG model
        print("Initializing DDPG model...")
        training_model = DDPG(
            policy="MlpPolicy",
            env=cheetah_environment,
            action_noise=action_noise,
            buffer_size=100000,
            learning_rate=1e-3,
            batch_size=256,
            gamma=0.99,
            verbose=1
        )

        # Setup logger with checkpoint saving capability
        print("Setting up training logger...")
        progress_logger = EnhancedTrainingLogger(
            log_filepath="efficient_cheetah_ddpg_training3.txt",
            save_dir="model_checkpoints",
            save_freq=50000,
            model_prefix="efficient_cheetah_ddpg3"
        )

        # Train the model
        print("Starting training for 1,000,000 timesteps...")
        training_model.learn(total_timesteps=1000000, callback=progress_logger)

        # Save the final model
        print("Saving final trained model...")
        training_model.save("efficient_cheetah_ddpg_final3")

        print("Training completed successfully!")
        print(f"Training logs saved to {progress_logger.log_filepath}")
        print(f"Model checkpoints saved in {progress_logger.save_dir}")
        
    except Exception as e:
        print(f"Training error occurred: {str(e)}")
        print("Training was interrupted, but intermediate models should be saved.")

if __name__ == "__main__":
    train_efficient_cheetah_with_ddpg()
# Out:
# Creating efficient cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -32.6    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 117      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -1.43    |
# |    critic_loss     | 0.0181   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -17.1    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 106      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -9.77    |
# |    critic_loss     | 0.124    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 101      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0702   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 99       |
# |    time_elapsed    | 160      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.201    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 31.6     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 98       |
# |    time_elapsed    | 202      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -32.1    |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 85.4     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 97       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -55.7    |
# |    critic_loss     | 2.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 99.7     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 97       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -80.3    |
# |    critic_loss     | 4.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 96       |
# |    time_elapsed    | 330      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 4.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 96       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 3.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 96       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 6.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 96       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 5.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 95       |
# |    time_elapsed    | 500      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 4.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_50000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 263      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 95       |
# |    time_elapsed    | 542      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -145     |
# |    critic_loss     | 7.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 296      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 95       |
# |    time_elapsed    | 584      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 7.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 331      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 95       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 10.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 383      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 95       |
# |    time_elapsed    | 669      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 12.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 379      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 95       |
# |    time_elapsed    | 711      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -163     |
# |    critic_loss     | 9.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 413      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 95       |
# |    time_elapsed    | 754      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -180     |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 468      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 95       |
# |    time_elapsed    | 796      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -184     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 474      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 95       |
# |    time_elapsed    | 838      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -189     |
# |    critic_loss     | 11.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 496      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 95       |
# |    time_elapsed    | 881      |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -187     |
# |    critic_loss     | 13.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 560      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 95       |
# |    time_elapsed    | 923      |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -195     |
# |    critic_loss     | 23.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 611      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 95       |
# |    time_elapsed    | 965      |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 18.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 663      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 95       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 17.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95899    |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 736      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 95       |
# |    time_elapsed    | 1050     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 15.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 825      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 95       |
# |    time_elapsed    | 1093     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -232     |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 926      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 95       |
# |    time_elapsed    | 1135     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 13.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 95       |
# |    time_elapsed    | 1178     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -261     |
# |    critic_loss     | 15.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 95       |
# |    time_elapsed    | 1220     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -264     |
# |    critic_loss     | 16       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.19e+03 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 95       |
# |    time_elapsed    | 1263     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -275     |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 94       |
# |    time_elapsed    | 1305     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -278     |
# |    critic_loss     | 16.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.39e+03 |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 94       |
# |    time_elapsed    | 1347     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 15       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.46e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 94       |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -290     |
# |    critic_loss     | 14.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.55e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 94       |
# |    time_elapsed    | 1432     |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -284     |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.64e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 94       |
# |    time_elapsed    | 1474     |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -306     |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.75e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 94       |
# |    time_elapsed    | 1517     |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -312     |
# |    critic_loss     | 18.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 94       |
# |    time_elapsed    | 1559     |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 23       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_150000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 94       |
# |    time_elapsed    | 1602     |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -334     |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.03e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 94       |
# |    time_elapsed    | 1644     |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -354     |
# |    critic_loss     | 21.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 94       |
# |    time_elapsed    | 1687     |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -351     |
# |    critic_loss     | 22.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 94       |
# |    time_elapsed    | 1729     |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -363     |
# |    critic_loss     | 24.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.34e+03 |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 94       |
# |    time_elapsed    | 1771     |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -378     |
# |    critic_loss     | 17.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 94       |
# |    time_elapsed    | 1814     |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -379     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.53e+03 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 94       |
# |    time_elapsed    | 1856     |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -389     |
# |    critic_loss     | 21       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.62e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 94       |
# |    time_elapsed    | 1898     |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -403     |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 94       |
# |    time_elapsed    | 1940     |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -408     |
# |    critic_loss     | 26.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.74e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 94       |
# |    time_elapsed    | 1982     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -411     |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.81e+03 |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 94       |
# |    time_elapsed    | 2024     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -429     |
# |    critic_loss     | 22.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.89e+03 |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 94       |
# |    time_elapsed    | 2067     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -430     |
# |    critic_loss     | 23.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_200000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.95e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 94       |
# |    time_elapsed    | 2109     |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -440     |
# |    critic_loss     | 27.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.02e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 94       |
# |    time_elapsed    | 2152     |
# |    total_timesteps | 204000   |
# | train/             |          |
# |    actor_loss      | -443     |
# |    critic_loss     | 29.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.07e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 94       |
# |    time_elapsed    | 2194     |
# |    total_timesteps | 208000   |
# | train/             |          |
# |    actor_loss      | -453     |
# |    critic_loss     | 32.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.12e+03 |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 94       |
# |    time_elapsed    | 2236     |
# |    total_timesteps | 212000   |
# | train/             |          |
# |    actor_loss      | -447     |
# |    critic_loss     | 29.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 211899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.17e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 94       |
# |    time_elapsed    | 2279     |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | -461     |
# |    critic_loss     | 25.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 94       |
# |    time_elapsed    | 2321     |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | -473     |
# |    critic_loss     | 40.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 94       |
# |    time_elapsed    | 2363     |
# |    total_timesteps | 224000   |
# | train/             |          |
# |    actor_loss      | -488     |
# |    critic_loss     | 28.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.37e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 94       |
# |    time_elapsed    | 2406     |
# |    total_timesteps | 228000   |
# | train/             |          |
# |    actor_loss      | -487     |
# |    critic_loss     | 32.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 227899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.46e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 94       |
# |    time_elapsed    | 2448     |
# |    total_timesteps | 232000   |
# | train/             |          |
# |    actor_loss      | -494     |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 231899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.47e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 94       |
# |    time_elapsed    | 2490     |
# |    total_timesteps | 236000   |
# | train/             |          |
# |    actor_loss      | -505     |
# |    critic_loss     | 27.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 235899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.56e+03 |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 94       |
# |    time_elapsed    | 2533     |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | -510     |
# |    critic_loss     | 33.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.59e+03 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 94       |
# |    time_elapsed    | 2575     |
# |    total_timesteps | 244000   |
# | train/             |          |
# |    actor_loss      | -518     |
# |    critic_loss     | 32.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 243899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.65e+03 |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 94       |
# |    time_elapsed    | 2617     |
# |    total_timesteps | 248000   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 33.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 247899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_250000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.73e+03 |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 94       |
# |    time_elapsed    | 2659     |
# |    total_timesteps | 252000   |
# | train/             |          |
# |    actor_loss      | -523     |
# |    critic_loss     | 38.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 251899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.79e+03 |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 94       |
# |    time_elapsed    | 2702     |
# |    total_timesteps | 256000   |
# | train/             |          |
# |    actor_loss      | -536     |
# |    critic_loss     | 40.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.84e+03 |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 94       |
# |    time_elapsed    | 2745     |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | -541     |
# |    critic_loss     | 36.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 259899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.92e+03 |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 94       |
# |    time_elapsed    | 2787     |
# |    total_timesteps | 264000   |
# | train/             |          |
# |    actor_loss      | -552     |
# |    critic_loss     | 34.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 263899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.99e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 94       |
# |    time_elapsed    | 2830     |
# |    total_timesteps | 268000   |
# | train/             |          |
# |    actor_loss      | -559     |
# |    critic_loss     | 40.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.04e+03 |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 94       |
# |    time_elapsed    | 2872     |
# |    total_timesteps | 272000   |
# | train/             |          |
# |    actor_loss      | -568     |
# |    critic_loss     | 57.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 271899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.1e+03  |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 94       |
# |    time_elapsed    | 2915     |
# |    total_timesteps | 276000   |
# | train/             |          |
# |    actor_loss      | -583     |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 275899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.2e+03  |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 94       |
# |    time_elapsed    | 2958     |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | -584     |
# |    critic_loss     | 42.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.3e+03  |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 94       |
# |    time_elapsed    | 3000     |
# |    total_timesteps | 284000   |
# | train/             |          |
# |    actor_loss      | -592     |
# |    critic_loss     | 37.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.36e+03 |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 94       |
# |    time_elapsed    | 3043     |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -598     |
# |    critic_loss     | 45.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.43e+03 |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 94       |
# |    time_elapsed    | 3085     |
# |    total_timesteps | 292000   |
# | train/             |          |
# |    actor_loss      | -604     |
# |    critic_loss     | 48.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 291899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.48e+03 |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 94       |
# |    time_elapsed    | 3128     |
# |    total_timesteps | 296000   |
# | train/             |          |
# |    actor_loss      | -615     |
# |    critic_loss     | 43.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_300000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.51e+03 |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 94       |
# |    time_elapsed    | 3170     |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -624     |
# |    critic_loss     | 34.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.59e+03 |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 94       |
# |    time_elapsed    | 3212     |
# |    total_timesteps | 304000   |
# | train/             |          |
# |    actor_loss      | -626     |
# |    critic_loss     | 55.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 303899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.69e+03 |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 94       |
# |    time_elapsed    | 3254     |
# |    total_timesteps | 308000   |
# | train/             |          |
# |    actor_loss      | -639     |
# |    critic_loss     | 33.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 307899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.78e+03 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 94       |
# |    time_elapsed    | 3297     |
# |    total_timesteps | 312000   |
# | train/             |          |
# |    actor_loss      | -637     |
# |    critic_loss     | 84.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 311899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.88e+03 |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 94       |
# |    time_elapsed    | 3339     |
# |    total_timesteps | 316000   |
# | train/             |          |
# |    actor_loss      | -654     |
# |    critic_loss     | 47.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 315899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.91e+03 |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 94       |
# |    time_elapsed    | 3382     |
# |    total_timesteps | 320000   |
# | train/             |          |
# |    actor_loss      | -655     |
# |    critic_loss     | 54.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 319899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 4.98e+03 |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 94       |
# |    time_elapsed    | 3424     |
# |    total_timesteps | 324000   |
# | train/             |          |
# |    actor_loss      | -669     |
# |    critic_loss     | 60.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 323899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.03e+03 |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 94       |
# |    time_elapsed    | 3467     |
# |    total_timesteps | 328000   |
# | train/             |          |
# |    actor_loss      | -667     |
# |    critic_loss     | 45.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 327899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.07e+03 |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 94       |
# |    time_elapsed    | 3509     |
# |    total_timesteps | 332000   |
# | train/             |          |
# |    actor_loss      | -677     |
# |    critic_loss     | 91.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 331899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.19e+03 |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 94       |
# |    time_elapsed    | 3552     |
# |    total_timesteps | 336000   |
# | train/             |          |
# |    actor_loss      | -676     |
# |    critic_loss     | 47.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 335899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.18e+03 |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 94       |
# |    time_elapsed    | 3594     |
# |    total_timesteps | 340000   |
# | train/             |          |
# |    actor_loss      | -686     |
# |    critic_loss     | 44.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.26e+03 |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 94       |
# |    time_elapsed    | 3637     |
# |    total_timesteps | 344000   |
# | train/             |          |
# |    actor_loss      | -684     |
# |    critic_loss     | 84.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 343899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.33e+03 |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 94       |
# |    time_elapsed    | 3679     |
# |    total_timesteps | 348000   |
# | train/             |          |
# |    actor_loss      | -698     |
# |    critic_loss     | 66.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 347899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_350000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.39e+03 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 94       |
# |    time_elapsed    | 3721     |
# |    total_timesteps | 352000   |
# | train/             |          |
# |    actor_loss      | -700     |
# |    critic_loss     | 56.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 351899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.47e+03 |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 94       |
# |    time_elapsed    | 3763     |
# |    total_timesteps | 356000   |
# | train/             |          |
# |    actor_loss      | -709     |
# |    critic_loss     | 48.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 355899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.53e+03 |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 94       |
# |    time_elapsed    | 3805     |
# |    total_timesteps | 360000   |
# | train/             |          |
# |    actor_loss      | -722     |
# |    critic_loss     | 50       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 359899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.59e+03 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 94       |
# |    time_elapsed    | 3847     |
# |    total_timesteps | 364000   |
# | train/             |          |
# |    actor_loss      | -725     |
# |    critic_loss     | 39.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 363899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.64e+03 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 94       |
# |    time_elapsed    | 3890     |
# |    total_timesteps | 368000   |
# | train/             |          |
# |    actor_loss      | -730     |
# |    critic_loss     | 46.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 367899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 5.7e+03  |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.66e+03  |
# | time/              |           |
# |    episodes        | 884       |
# |    fps             | 94        |
# |    time_elapsed    | 9372      |
# |    total_timesteps | 884000    |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 108       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 883899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.65e+03  |
# | time/              |           |
# |    episodes        | 888       |
# |    fps             | 94        |
# |    time_elapsed    | 9414      |
# |    total_timesteps | 888000    |
# | train/             |           |
# |    actor_loss      | -1.07e+03 |
# |    critic_loss     | 66.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 887899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.73e+03 |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 94       |
# |    time_elapsed    | 9457     |
# |    total_timesteps | 892000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 68.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 891899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.82e+03  |
# | time/              |           |
# |    episodes        | 896       |
# |    fps             | 94        |
# |    time_elapsed    | 9500      |
# |    total_timesteps | 896000    |
# | train/             |           |
# |    actor_loss      | -1.08e+03 |
# |    critic_loss     | 113       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 895899    |
# ----------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_900000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.89e+03 |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 94       |
# |    time_elapsed    | 9542     |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 94.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 899899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.96e+03  |
# | time/              |           |
# |    episodes        | 904       |
# |    fps             | 94        |
# |    time_elapsed    | 9585      |
# |    total_timesteps | 904000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 108       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 903899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.94e+03  |
# | time/              |           |
# |    episodes        | 908       |
# |    fps             | 94        |
# |    time_elapsed    | 9627      |
# |    total_timesteps | 908000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 90.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 907899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.98e+03  |
# | time/              |           |
# |    episodes        | 912       |
# |    fps             | 94        |
# |    time_elapsed    | 9670      |
# |    total_timesteps | 912000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 79.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 911899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.98e+03  |
# | time/              |           |
# |    episodes        | 916       |
# |    fps             | 94        |
# |    time_elapsed    | 9712      |
# |    total_timesteps | 916000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 59.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 915899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9e+03    |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 94       |
# |    time_elapsed    | 9755     |
# |    total_timesteps | 920000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 76.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 919899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.99e+03  |
# | time/              |           |
# |    episodes        | 924       |
# |    fps             | 94        |
# |    time_elapsed    | 9797      |
# |    total_timesteps | 924000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 107       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 923899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.96e+03 |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 94       |
# |    time_elapsed    | 9840     |
# |    total_timesteps | 928000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 62.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 927899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 9.01e+03  |
# | time/              |           |
# |    episodes        | 932       |
# |    fps             | 94        |
# |    time_elapsed    | 9882      |
# |    total_timesteps | 932000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 125       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 931899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.02e+03 |
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 94       |
# |    time_elapsed    | 9925     |
# |    total_timesteps | 936000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 78.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 935899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 94       |
# |    time_elapsed    | 9967     |
# |    total_timesteps | 940000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 93.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 939899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 9.08e+03  |
# | time/              |           |
# |    episodes        | 944       |
# |    fps             | 94        |
# |    time_elapsed    | 10009     |
# |    total_timesteps | 944000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 78.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 943899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.98e+03 |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 94       |
# |    time_elapsed    | 10052    |
# |    total_timesteps | 948000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 102      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 947899   |
# ---------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_950000
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.92e+03  |
# | time/              |           |
# |    episodes        | 952       |
# |    fps             | 94        |
# |    time_elapsed    | 10095     |
# |    total_timesteps | 952000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 82.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 951899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.89e+03  |
# | time/              |           |
# |    episodes        | 956       |
# |    fps             | 94        |
# |    time_elapsed    | 10138     |
# |    total_timesteps | 956000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 68.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 955899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.92e+03  |
# | time/              |           |
# |    episodes        | 960       |
# |    fps             | 94        |
# |    time_elapsed    | 10181     |
# |    total_timesteps | 960000    |
# | train/             |           |
# |    actor_loss      | -1.11e+03 |
# |    critic_loss     | 82.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 959899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.92e+03  |
# | time/              |           |
# |    episodes        | 964       |
# |    fps             | 94        |
# |    time_elapsed    | 10224     |
# |    total_timesteps | 964000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 110       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 963899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.98e+03  |
# | time/              |           |
# |    episodes        | 968       |
# |    fps             | 94        |
# |    time_elapsed    | 10267     |
# |    total_timesteps | 968000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 92.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 967899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.92e+03 |
# | time/              |          |
# |    episodes        | 972      |
# |    fps             | 94       |
# |    time_elapsed    | 10310    |
# |    total_timesteps | 972000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 112      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 971899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.86e+03  |
# | time/              |           |
# |    episodes        | 976       |
# |    fps             | 94        |
# |    time_elapsed    | 10353     |
# |    total_timesteps | 976000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 78.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 975899    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.87e+03 |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 94       |
# |    time_elapsed    | 10395    |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 93       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 979899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.85e+03 |
# | time/              |          |
# |    episodes        | 984      |
# |    fps             | 94       |
# |    time_elapsed    | 10438    |
# |    total_timesteps | 984000   |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 72.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 983899   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.89e+03  |
# | time/              |           |
# |    episodes        | 988       |
# |    fps             | 94        |
# |    time_elapsed    | 10480     |
# |    total_timesteps | 988000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 104       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 987899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.83e+03  |
# | time/              |           |
# |    episodes        | 992       |
# |    fps             | 94        |
# |    time_elapsed    | 10523     |
# |    total_timesteps | 992000    |
# | train/             |           |
# |    actor_loss      | -1.09e+03 |
# |    critic_loss     | 86        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 991899    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | 8.79e+03  |
# | time/              |           |
# |    episodes        | 996       |
# |    fps             | 94        |
# |    time_elapsed    | 10565     |
# |    total_timesteps | 996000    |
# | train/             |           |
# |    actor_loss      | -1.05e+03 |
# |    critic_loss     | 107       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 995899    |
# ----------------------------------
# Model saved at model_checkpoints/efficient_cheetah_ddpg3_1000000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 8.79e+03 |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 94       |
# |    time_elapsed    | 10607    |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | -1.1e+03 |
# |    critic_loss     | 84.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999899   |
# ---------------------------------
# Saving final trained model...
# Training completed successfully!
# Training logs saved to efficient_cheetah_ddpg_training3.txt
# Model checkpoints saved in model_checkpoints
