# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="anti_inversion_ddpg_training2.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="anti_inversion_ddpg2"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):

        if self.num_timesteps >= self.last_save + self.save_freq:
            model_path = os.path.join(self.save_dir, f"{self.model_prefix}_{self.num_timesteps}")
            self.model.save(model_path)
            print(f"Model saved at {model_path}")
            self.last_save = self.num_timesteps
        

        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        

        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class AntiInversionCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.modified_reward_function(observation, action, original_reward)
        return observation, modified_reward, terminated, truncated, info
    
    def modified_reward_function(self, observation, action, original_reward):
        # Get TRUE torso angle (using the correct index)
        torso_angle = observation[1]  # rooty - actual torso angle
        
        # Simple posture penalty based on cosine of the angle
        posture_penalty = -1.0 * min(0, np.cos(torso_angle))
        
        # Original reward weight
        original_reward_weight = 1.0
        
        # Combined reward
        reward = posture_penalty + original_reward_weight * original_reward
        
        return reward

def train_anti_inversion_with_ddpg():
    # Setup environment
    print("Creating anti-inversion cheetah environment...")
    cheetah_environment = AntiInversionCheetahEnv()

    # Action noise for exploration
    n_actions = cheetah_environment.action_space.shape[0]
    action_noise = NormalActionNoise(
        mean=np.zeros(n_actions),
        sigma=0.1 * np.ones(n_actions)
    )

    # Initialize DDPG model
    print("Initializing DDPG model...")
    training_model = DDPG(
        policy="MlpPolicy",
        env=cheetah_environment,
        action_noise=action_noise,
        buffer_size=100000,
        learning_rate=1e-3,
        batch_size=256,
        gamma=0.99,
        verbose=1
    )

    # Setup logger with checkpoint saving capability
    print("Setting up training logger...")
    progress_logger = EnhancedTrainingLogger(
        log_filepath="anti_inversion_ddpg_training2.txt",
        save_dir="model_checkpoints",
        save_freq=50000,
        model_prefix="anti_inversion_ddpg2"
    )

    # Train the model
    print("Starting training for 1,000,000 timesteps...")
    training_model.learn(total_timesteps=1000000, callback=progress_logger)

    # Save the final model
    print("Saving final trained model...")
    training_model.save("anti_inversion_ddpg_final2")

    print("Training completed!")
    print(f"Training logs saved to {progress_logger.log_filepath}")
    print(f"Model checkpoints saved in {progress_logger.save_dir}")

if __name__ == "__main__":
    train_anti_inversion_with_ddpg()
# Out:
# Creating anti-inversion cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -37.8    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 14       |
# |    time_elapsed    | 284      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -6.44    |
# |    critic_loss     | 0.031    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 47.8     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 13       |
# |    time_elapsed    | 576      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -27.1    |
# |    critic_loss     | 0.672    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 13       |
# |    time_elapsed    | 871      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 2        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 13       |
# |    time_elapsed    | 1164     |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -74.8    |
# |    critic_loss     | 2.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 13       |
# |    time_elapsed    | 1460     |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 3.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 178      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 13       |
# |    time_elapsed    | 1754     |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 3.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 223      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 13       |
# |    time_elapsed    | 2052     |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 4.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 13       |
# |    time_elapsed    | 2350     |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 3.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 258      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 13       |
# |    time_elapsed    | 2648     |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 3.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 283      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 13       |
# |    time_elapsed    | 2943     |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 3.49     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 13       |
# |    time_elapsed    | 3240     |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 4.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 13       |
# |    time_elapsed    | 3535     |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 3.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg2_50000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 336      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 13       |
# |    time_elapsed    | 3830     |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 3.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 361      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 13       |
# |    time_elapsed    | 4126     |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 3.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 384      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 13       |
# |    time_elapsed    | 4421     |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -130     |
# |    critic_loss     | 3.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 411      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 13       |
# |    time_elapsed    | 4716     |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 5.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 430      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 13       |
# |    time_elapsed    | 5010     |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 4.75     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 449      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 13       |
# |    time_elapsed    | 5309     |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 5.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 469      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 13       |
# |    time_elapsed    | 5604     |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 4.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 491      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 13       |
# |    time_elapsed    | 5898     |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -134     |
# |    critic_loss     | 4.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 512      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 13       |
# |    time_elapsed    | 6192     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 6.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 532      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 13       |
# |    time_elapsed    | 6488     |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -140     |
# |    critic_loss     | 5.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 566      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 13       |
# |    time_elapsed    | 6780     |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -146     |
# |    critic_loss     | 6.45     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 589      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 13       |
# |    time_elapsed    | 7075     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 11       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95899    |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg2_100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 611      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 13       |
# |    time_elapsed    | 7372     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -150     |
# |    critic_loss     | 11.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 650      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 13       |
# |    time_elapsed    | 7669     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -159     |
# |    critic_loss     | 22.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 707      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 13       |
# |    time_elapsed    | 7964     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -168     |
# |    critic_loss     | 8.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 751      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 13       |
# |    time_elapsed    | 8260     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -165     |
# |    critic_loss     | 9.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 794      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 13       |
# |    time_elapsed    | 8557     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 10.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 854      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 13       |
# |    time_elapsed    | 8852     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -169     |
# |    critic_loss     | 10.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 909      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 13       |
# |    time_elapsed    | 9149     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -177     |
# |    critic_loss     | 8.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 955      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 13       |
# |    time_elapsed    | 9447     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -183     |
# |    critic_loss     | 10.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.02e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 13       |
# |    time_elapsed    | 9743     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -183     |
# |    critic_loss     | 10.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.09e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 13       |
# |    time_elapsed    | 10039    |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 13.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.13e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 13       |
# |    time_elapsed    | 10335    |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -208     |
# |    critic_loss     | 36.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.18e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 13       |
# |    time_elapsed    | 10631    |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -208     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 13       |
# |    time_elapsed    | 10927    |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -211     |
# |    critic_loss     | 14.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg2_150000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.28e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 13       |
# |    time_elapsed    | 11222    |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 44.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.33e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 13       |
# |    time_elapsed    | 11519    |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -242     |
# |    critic_loss     | 26.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.36e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 13       |
# |    time_elapsed    | 11814    |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 59.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.36e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 13       |
# |    time_elapsed    | 12110    |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -283     |
# |    critic_loss     | 69.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.36e+03 |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 13       |
# |    time_elapsed    | 12407    |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -288     |
# |    critic_loss     | 55.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.33e+03 |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 13       |
# |    time_elapsed    | 12701    |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 40       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.28e+03 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 13       |
# |    time_elapsed    | 12997    |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -321     |
# |    critic_loss     | 24.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 13       |
# |    time_elapsed    | 13294    |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -322     |
# |    critic_loss     | 52.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 13       |
# |    time_elapsed    | 13589    |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -323     |
# |    critic_loss     | 23.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 13       |
# |    time_elapsed    | 13883    |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -324     |
# |    critic_loss     | 40.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.28e+03 |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 13       |
# |    time_elapsed    | 14180    |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 51       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.3e+03  |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 13       |
# |    time_elapsed    | 14479    |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -350     |
# |    critic_loss     | 33.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg2_200000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.32e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 13       |
# |    time_elapsed    | 14779    |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -349     |
# |    critic_loss     | 36.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.35e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 13       |
# |    time_elapsed    | 15078    |
# |    total_timesteps | 204000   |
# | train/             |          |
# |    actor_loss      | -370     |
# |    critic_loss     | 32.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.31e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 13       |
# |    time_elapsed    | 15374    |
# |    total_timesteps | 208000   |
# | train/             |          |
# |    actor_loss      | -361     |
# |    critic_loss     | 28.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.3e+03  |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 13       |
# |    time_elapsed    | 15672    |
# |    total_timesteps | 212000   |
# | train/             |          |
# |    actor_loss      | -351     |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 211899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.24e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 13       |
# |    time_elapsed    | 15972    |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | -334     |
# |    critic_loss     | 20.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.27e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 13       |
# |    time_elapsed    | 16272    |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | -322     |
# |    critic_loss     | 17.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.3e+03  |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 13       |
# |    time_elapsed    | 16572    |
# |    total_timesteps | 224000   |
# | train/             |          |
# |    actor_loss      | -315     |
# |    critic_loss     | 26.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.29e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 13       |
# |    time_elapsed    | 16874    |
# |    total_timesteps | 228000   |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 27.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 227899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.33e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 13       |
# |    time_elapsed    | 17176    |
# |    total_timesteps | 232000   |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 27.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 231899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.38e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 13       |
# |    time_elapsed    | 17478    |
# |    total_timesteps | 236000   |
# | train/             |          |
# |    actor_loss      | -312     |
# |    critic_loss     | 30.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 235899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 13       |
# |    time_elapsed    | 19904    |
# |    total_timesteps | 268000   |
# | train/             |          |
# |    actor_loss      | -361     |
# |    critic_loss     | 39.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 13       |
# |    time_elapsed    | 20209    |
# |    total_timesteps | 272000   |
# | train/             |          |
# |    actor_loss      | -371     |
# |    critic_loss     | 33.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 271899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 13       |
# |    time_elapsed    | 20514    |
# |    total_timesteps | 276000   |
# | train/             |          |
# |    actor_loss      | -378     |
# |    critic_loss     | 47       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 275899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.42e+03 |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 13       |
# |    time_elapsed    | 20819    |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | -394     |
# |    critic_loss     | 42.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.53e+03 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 13       |
# |    time_elapsed    | 21123    |
# |    total_timesteps | 284000   |
# | train/             |          |
# |    actor_loss      | -402     |
# |    critic_loss     | 48.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.63e+03 |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 13       |
# |    time_elapsed    | 21426    |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -446     |
# |    critic_loss     | 32.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 13       |
# |    time_elapsed    | 21730    |
# |    total_timesteps | 292000   |
# | train/             |          |
# |    actor_loss      | -421     |
# |    critic_loss     | 53.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 291899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.78e+03 |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 13       |
# |    time_elapsed    | 22033    |
# |    total_timesteps | 296000   |
# | train/             |          |
# |    actor_loss      | -433     |
# |    critic_loss     | 47.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg2_300000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.86e+03 |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 13       |
# |    time_elapsed    | 22336    |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -427     |
# |    critic_loss     | 45.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.96e+03 |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 13       |
# |    time_elapsed    | 22639    |
# |    total_timesteps | 304000   |
# | train/             |          |
# |    actor_loss      | -454     |
# |    critic_loss     | 54.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 303899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.1e+03  |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 13       |
# |    time_elapsed    | 22943    |
# |    total_timesteps | 308000   |
# | train/             |          |
# |    actor_loss      | -450     |
# |    critic_loss     | 53.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 307899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 13       |
# |    time_elapsed    | 23248    |
# |    total_timesteps | 312000   |
# | train/             |          |
# |    actor_loss      | -499     |
# |    critic_loss     | 39.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 311899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 3.4e+03  |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 13       |
# |    time_elapsed    | 23550    |
# |    total_timesteps | 316000   |
# | train/             |          |
# |    actor_loss      | -497     |
# |    critic_loss     | 45.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 315899   |
# ---------------------------------

# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import DDPG
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="anti_inversion_ddpg_training3.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="anti_inversion_ddpg3"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            model_path = os.path.join(self.save_dir, f"{self.model_prefix}_{self.num_timesteps}")
            self.model.save(model_path)
            print(f"Model saved at {model_path}")
            self.last_save = self.num_timesteps
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class AntiInversionCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.modified_reward_function(observation, action, original_reward)
        return observation, modified_reward, terminated, truncated, info
    
    def modified_reward_function(self, observation, action, original_reward):
        # Get TRUE torso angle (using the correct index)
        torso_angle = observation[1]  # rooty - actual torso angle
        
        # Simple posture penalty based on cosine of the angle
        posture_penalty = -1.0 * min(0, np.cos(torso_angle))
        
        # Original reward weight
        original_reward_weight = 1.0
        
        # Combined reward
        reward = posture_penalty + original_reward_weight * original_reward
        
        return reward

def train_anti_inversion_with_ddpg():
    # Setup environment
    print("Creating anti-inversion cheetah environment...")
    cheetah_environment = AntiInversionCheetahEnv()

    # Action noise for exploration
    n_actions = cheetah_environment.action_space.shape[0]
    action_noise = NormalActionNoise(
        mean=np.zeros(n_actions),
        sigma=0.1 * np.ones(n_actions)
    )

    # Initialize DDPG model
    print("Initializing DDPG model...")
    training_model = DDPG(
        policy="MlpPolicy",
        env=cheetah_environment,
        action_noise=action_noise,
        buffer_size=100000,
        learning_rate=1e-3,
        batch_size=256,
        gamma=0.99,
        verbose=1
    )

    # Setup logger with checkpoint saving capability
    print("Setting up training logger...")
    progress_logger = EnhancedTrainingLogger(
        log_filepath="anti_inversion_ddpg_training3.txt",
        save_dir="model_checkpoints",
        save_freq=50000,
        model_prefix="anti_inversion_ddpg3"
    )

    # Train the model
    print("Starting training for 1,000,000 timesteps...")
    training_model.learn(total_timesteps=1000000, callback=progress_logger)

    # Save the final model
    print("Saving final trained model...")
    training_model.save("anti_inversion_ddpg_final3")

    print("Training completed!")
    print(f"Training logs saved to {progress_logger.log_filepath}")
    print(f"Model checkpoints saved in {progress_logger.save_dir}")

if __name__ == "__main__":
    train_anti_inversion_with_ddpg()
# Out:
# Creating anti-inversion cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing DDPG model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 94.3     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 104      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -6.06    |
# |    critic_loss     | 0.0675   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 99       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.153    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 351      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 97       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 0.801    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 497      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 96       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 1.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 570      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 96       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -82.2    |
# |    critic_loss     | 1.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 645      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 95       |
# |    time_elapsed    | 250      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 728      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 95       |
# |    time_elapsed    | 292      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 2.79     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 95       |
# |    time_elapsed    | 335      |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | -135     |
# |    critic_loss     | 4.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 698      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 95       |
# |    time_elapsed    | 377      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -154     |
# |    critic_loss     | 5.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 673      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 95       |
# |    time_elapsed    | 420      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -161     |
# |    critic_loss     | 4.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 755      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 95       |
# |    time_elapsed    | 463      |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 3.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 831      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 94       |
# |    time_elapsed    | 505      |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | -173     |
# |    critic_loss     | 3.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47899    |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_50000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 902      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 94       |
# |    time_elapsed    | 548      |
# |    total_timesteps | 52000    |
# | train/             |          |
# |    actor_loss      | -181     |
# |    critic_loss     | 3.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 949      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 94       |
# |    time_elapsed    | 590      |
# |    total_timesteps | 56000    |
# | train/             |          |
# |    actor_loss      | -192     |
# |    critic_loss     | 3.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 55899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 993      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 94       |
# |    time_elapsed    | 633      |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 3.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.04e+03 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 94       |
# |    time_elapsed    | 675      |
# |    total_timesteps | 64000    |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 2.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 94       |
# |    time_elapsed    | 717      |
# |    total_timesteps | 68000    |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 3.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 67899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.11e+03 |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 94       |
# |    time_elapsed    | 760      |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -210     |
# |    critic_loss     | 2.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.15e+03 |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 94       |
# |    time_elapsed    | 803      |
# |    total_timesteps | 76000    |
# | train/             |          |
# |    actor_loss      | -212     |
# |    critic_loss     | 2.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 75899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.17e+03 |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 94       |
# |    time_elapsed    | 846      |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 4.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.16e+03 |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 94       |
# |    time_elapsed    | 889      |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 2.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.19e+03 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 94       |
# |    time_elapsed    | 932      |
# |    total_timesteps | 88000    |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 2.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 87899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.21e+03 |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 94       |
# |    time_elapsed    | 974      |
# |    total_timesteps | 92000    |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 3.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 91899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.23e+03 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 94       |
# |    time_elapsed    | 1017     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -214     |
# |    critic_loss     | 2.68     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 95899    |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_100000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.26e+03 |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 94       |
# |    time_elapsed    | 1059     |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 2.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.33e+03 |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 94       |
# |    time_elapsed    | 1102     |
# |    total_timesteps | 104000   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 2.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 103899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.39e+03 |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 94       |
# |    time_elapsed    | 1144     |
# |    total_timesteps | 108000   |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 2.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 107899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.44e+03 |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 94       |
# |    time_elapsed    | 1187     |
# |    total_timesteps | 112000   |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 2.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 111899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.48e+03 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 94       |
# |    time_elapsed    | 1229     |
# |    total_timesteps | 116000   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 2.85     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.52e+03 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 94       |
# |    time_elapsed    | 1272     |
# |    total_timesteps | 120000   |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 2.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 119899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.55e+03 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 94       |
# |    time_elapsed    | 1315     |
# |    total_timesteps | 124000   |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 2.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 123899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.58e+03 |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 94       |
# |    time_elapsed    | 1358     |
# |    total_timesteps | 128000   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 2.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.59e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 94       |
# |    time_elapsed    | 1401     |
# |    total_timesteps | 132000   |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 131899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.67e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 94       |
# |    time_elapsed    | 1444     |
# |    total_timesteps | 136000   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 2.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.73e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 94       |
# |    time_elapsed    | 1486     |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 1.95     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.74e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 94       |
# |    time_elapsed    | 1529     |
# |    total_timesteps | 144000   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 1.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 143899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.75e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 94       |
# |    time_elapsed    | 1571     |
# |    total_timesteps | 148000   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 1.55     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 147899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_150000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.75e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 94       |
# |    time_elapsed    | 1614     |
# |    total_timesteps | 152000   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 2.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 151899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.76e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 94       |
# |    time_elapsed    | 1656     |
# |    total_timesteps | 156000   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 1.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 155899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.78e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 94       |
# |    time_elapsed    | 1699     |
# |    total_timesteps | 160000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 1.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 159899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.78e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 94       |
# |    time_elapsed    | 1741     |
# |    total_timesteps | 164000   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 1.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 163899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.8e+03  |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 94       |
# |    time_elapsed    | 1784     |
# |    total_timesteps | 168000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 1.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.8e+03  |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 94       |
# |    time_elapsed    | 1826     |
# |    total_timesteps | 172000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 171899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.81e+03 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 94       |
# |    time_elapsed    | 1868     |
# |    total_timesteps | 176000   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 94       |
# |    time_elapsed    | 1911     |
# |    total_timesteps | 180000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 1.88     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 94       |
# |    time_elapsed    | 1954     |
# |    total_timesteps | 184000   |
# | train/             |          |
# |    actor_loss      | -225     |
# |    critic_loss     | 1.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 183899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 94       |
# |    time_elapsed    | 1997     |
# |    total_timesteps | 188000   |
# | train/             |          |
# |    actor_loss      | -225     |
# |    critic_loss     | 2        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 94       |
# |    time_elapsed    | 2039     |
# |    total_timesteps | 192000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 94       |
# |    time_elapsed    | 2082     |
# |    total_timesteps | 196000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 2.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_200000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 94       |
# |    time_elapsed    | 2124     |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 94       |
# |    time_elapsed    | 2167     |
# |    total_timesteps | 204000   |
# | train/             |          |
# |    actor_loss      | -229     |
# |    critic_loss     | 1.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 203899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 94       |
# |    time_elapsed    | 2209     |
# |    total_timesteps | 208000   |
# | train/             |          |
# |    actor_loss      | -230     |
# |    critic_loss     | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 94       |
# |    time_elapsed    | 2252     |
# |    total_timesteps | 212000   |
# | train/             |          |
# |    actor_loss      | -229     |
# |    critic_loss     | 1.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 211899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 94       |
# |    time_elapsed    | 2295     |
# |    total_timesteps | 216000   |
# | train/             |          |
# |    actor_loss      | -229     |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 215899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 94       |
# |    time_elapsed    | 2337     |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 2        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 94       |
# |    time_elapsed    | 2379     |
# |    total_timesteps | 224000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 94       |
# |    time_elapsed    | 2422     |
# |    total_timesteps | 228000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 2.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 227899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.83e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 94       |
# |    time_elapsed    | 2464     |
# |    total_timesteps | 232000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 0.919    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 231899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 94       |
# |    time_elapsed    | 2507     |
# |    total_timesteps | 236000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 235899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 94       |
# |    time_elapsed    | 2549     |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 2.54     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 94       |
# |    time_elapsed    | 2592     |
# |    total_timesteps | 244000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 0.876    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 243899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 94       |
# |    time_elapsed    | 2635     |
# |    total_timesteps | 248000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 247899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_250000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 94       |
# |    time_elapsed    | 2677     |
# |    total_timesteps | 252000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 251899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 94       |
# |    time_elapsed    | 2720     |
# |    total_timesteps | 256000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 255899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 94       |
# |    time_elapsed    | 2762     |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 259899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 94       |
# |    time_elapsed    | 2804     |
# |    total_timesteps | 264000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 263899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.88e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 94       |
# |    time_elapsed    | 2847     |
# |    total_timesteps | 268000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 1.33     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 94       |
# |    time_elapsed    | 2889     |
# |    total_timesteps | 272000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 1.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 271899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 94       |
# |    time_elapsed    | 2932     |
# |    total_timesteps | 276000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 1.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 275899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 94       |
# |    time_elapsed    | 2974     |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 1.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 94       |
# |    time_elapsed    | 3017     |
# |    total_timesteps | 284000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 2.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 283899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 94       |
# |    time_elapsed    | 3059     |
# |    total_timesteps | 288000   |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 1.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 94       |
# |    time_elapsed    | 3102     |
# |    total_timesteps | 292000   |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 1.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 291899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 94       |
# |    time_elapsed    | 3145     |
# |    total_timesteps | 296000   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 1.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 295899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_300000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.9e+03  |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 94       |
# |    time_elapsed    | 3187     |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 2.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.92e+03 |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 94       |
# |    time_elapsed    | 3230     |
# |    total_timesteps | 304000   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 1.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 303899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.94e+03 |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 94       |
# |    time_elapsed    | 3272     |
# |    total_timesteps | 308000   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 1.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 307899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.95e+03 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 94       |
# |    time_elapsed    | 3315     |
# |    total_timesteps | 312000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 311899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 94       |
# |    time_elapsed    | 3358     |
# |    total_timesteps | 316000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 315899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.96e+03 |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 94       |
# |    time_elapsed    | 3401     |
# |    total_timesteps | 320000   |
# | train/             |          |
# |    actor_loss      | -225     |
# |    critic_loss     | 1.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 319899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.97e+03 |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 94       |
# |    time_elapsed    | 3444     |
# |    total_timesteps | 324000   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 323899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.98e+03 |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 94       |
# |    time_elapsed    | 3486     |
# |    total_timesteps | 328000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 327899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 94       |
# |    time_elapsed    | 3529     |
# |    total_timesteps | 332000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 331899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 94       |
# |    time_elapsed    | 3571     |
# |    total_timesteps | 336000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 335899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 94       |
# |    time_elapsed    | 3614     |
# |    total_timesteps | 340000   |
# | train/             |          |
# |    actor_loss      | -226     |
# |    critic_loss     | 1.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 94       |
# |    time_elapsed    | 3656     |
# |    total_timesteps | 344000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 2.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 343899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 94       |
# |    time_elapsed    | 3699     |
# |    total_timesteps | 348000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 347899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_350000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 94       |
# |    time_elapsed    | 3741     |
# |    total_timesteps | 352000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 351899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 94       |
# |    time_elapsed    | 3784     |
# |    total_timesteps | 356000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 355899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 94       |
# |    time_elapsed    | 3827     |
# |    total_timesteps | 360000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 0.801    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 359899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 94       |
# |    time_elapsed    | 3870     |
# |    total_timesteps | 364000   |
# | train/             |          |
# |    actor_loss      | -227     |
# |    critic_loss     | 1.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 363899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.01e+03 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 94       |
# |    time_elapsed    | 3914     |
# |    total_timesteps | 368000   |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 1.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 367899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.03e+03 |
# | time/              |          |
# ...
# |    episodes        | 880      |
# |    fps             | 93       |
# |    time_elapsed    | 9375     |
# |    total_timesteps | 880000   |
# | train/             |          |
# |    actor_loss      | -244     |
# |    critic_loss     | 1.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 879899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 884      |
# |    fps             | 93       |
# |    time_elapsed    | 9417     |
# |    total_timesteps | 884000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 883899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.12e+03 |
# | time/              |          |
# |    episodes        | 888      |
# |    fps             | 93       |
# |    time_elapsed    | 9459     |
# |    total_timesteps | 888000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 2.46     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 887899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 892      |
# |    fps             | 93       |
# |    time_elapsed    | 9502     |
# |    total_timesteps | 892000   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 1.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 891899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 896      |
# |    fps             | 93       |
# |    time_elapsed    | 9544     |
# |    total_timesteps | 896000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 1.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 895899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_900000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 93       |
# |    time_elapsed    | 9586     |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 899899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 904      |
# |    fps             | 93       |
# |    time_elapsed    | 9629     |
# |    total_timesteps | 904000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 2.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 903899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 908      |
# |    fps             | 93       |
# |    time_elapsed    | 9671     |
# |    total_timesteps | 908000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 1.84     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 907899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 912      |
# |    fps             | 93       |
# |    time_elapsed    | 9713     |
# |    total_timesteps | 912000   |
# | train/             |          |
# |    actor_loss      | -248     |
# |    critic_loss     | 1.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 911899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.15e+03 |
# | time/              |          |
# |    episodes        | 916      |
# |    fps             | 93       |
# |    time_elapsed    | 9756     |
# |    total_timesteps | 916000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 1.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 915899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 93       |
# |    time_elapsed    | 9798     |
# |    total_timesteps | 920000   |
# | train/             |          |
# |    actor_loss      | -244     |
# |    critic_loss     | 2.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 919899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.12e+03 |
# | time/              |          |
# |    episodes        | 924      |
# |    fps             | 93       |
# |    time_elapsed    | 9840     |
# |    total_timesteps | 924000   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 2.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 923899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 93       |
# |    time_elapsed    | 9882     |
# |    total_timesteps | 928000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 1.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 927899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 93       |
# |    time_elapsed    | 9925     |
# |    total_timesteps | 932000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 1.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 931899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 936      |
# |    fps             | 93       |
# |    time_elapsed    | 9967     |
# |    total_timesteps | 936000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 2.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 935899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.15e+03 |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 93       |
# |    time_elapsed    | 10010    |
# |    total_timesteps | 940000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 1.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 939899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.16e+03 |
# | time/              |          |
# |    episodes        | 944      |
# |    fps             | 93       |
# |    time_elapsed    | 10052    |
# |    total_timesteps | 944000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 2.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 943899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.17e+03 |
# | time/              |          |
# |    episodes        | 948      |
# |    fps             | 93       |
# |    time_elapsed    | 10095    |
# |    total_timesteps | 948000   |
# | train/             |          |
# |    actor_loss      | -248     |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 947899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_950000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.17e+03 |
# | time/              |          |
# |    episodes        | 952      |
# |    fps             | 93       |
# |    time_elapsed    | 10138    |
# |    total_timesteps | 952000   |
# | train/             |          |
# |    actor_loss      | -244     |
# |    critic_loss     | 1.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 951899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.18e+03 |
# | time/              |          |
# |    episodes        | 956      |
# |    fps             | 93       |
# |    time_elapsed    | 10181    |
# |    total_timesteps | 956000   |
# | train/             |          |
# |    actor_loss      | -248     |
# |    critic_loss     | 1.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 955899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.18e+03 |
# | time/              |          |
# |    episodes        | 960      |
# |    fps             | 93       |
# |    time_elapsed    | 10224    |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 2.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 959899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.19e+03 |
# | time/              |          |
# |    episodes        | 964      |
# |    fps             | 93       |
# |    time_elapsed    | 10267    |
# |    total_timesteps | 964000   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 963899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 968      |
# |    fps             | 93       |
# |    time_elapsed    | 10309    |
# |    total_timesteps | 968000   |
# | train/             |          |
# |    actor_loss      | -246     |
# |    critic_loss     | 1.69     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 967899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 972      |
# |    fps             | 93       |
# |    time_elapsed    | 10352    |
# |    total_timesteps | 972000   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 1.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 971899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.2e+03  |
# | time/              |          |
# |    episodes        | 976      |
# |    fps             | 93       |
# |    time_elapsed    | 10394    |
# |    total_timesteps | 976000   |
# | train/             |          |
# |    actor_loss      | -247     |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 975899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 93       |
# |    time_elapsed    | 10437    |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | -251     |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 979899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 984      |
# |    fps             | 93       |
# |    time_elapsed    | 10479    |
# |    total_timesteps | 984000   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 1.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 983899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.21e+03 |
# | time/              |          |
# |    episodes        | 988      |
# |    fps             | 93       |
# |    time_elapsed    | 10521    |
# |    total_timesteps | 988000   |
# | train/             |          |
# |    actor_loss      | -245     |
# |    critic_loss     | 2        |
# |    learning_rate   | 0.001    |
# |    n_updates       | 987899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 992      |
# |    fps             | 93       |
# |    time_elapsed    | 10563    |
# |    total_timesteps | 992000   |
# | train/             |          |
# |    actor_loss      | -248     |
# |    critic_loss     | 2.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 991899   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 996      |
# |    fps             | 93       |
# |    time_elapsed    | 10604    |
# |    total_timesteps | 996000   |
# | train/             |          |
# |    actor_loss      | -249     |
# |    critic_loss     | 1.82     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 995899   |
# ---------------------------------
# Model saved at model_checkpoints/anti_inversion_ddpg3_1000000
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 94       |
# |    time_elapsed    | 10637    |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | -250     |
# |    critic_loss     | 1.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999899   |
# ---------------------------------
# Saving final trained model...
# Training completed!
# Training logs saved to anti_inversion_ddpg_training3.txt
# Model checkpoints saved in model_checkpoints
