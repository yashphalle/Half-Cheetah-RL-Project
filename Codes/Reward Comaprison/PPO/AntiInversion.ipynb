# %%
import gymnasium as gym
import numpy as np
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback

class EnhancedTrainingLogger(BaseCallback):
    def __init__(self, log_filepath="anti_inversion_ppo_training2.txt", save_dir="model_checkpoints", 
                 save_freq=50000, model_prefix="anti_inversion_ppo"):
        super().__init__(verbose=0)
        self.log_filepath = log_filepath
        self.save_dir = save_dir
        self.save_freq = save_freq
        self.model_prefix = model_prefix
        self.episode_total_reward = 0
        self.control_costs = 0
        self.last_save = 0
        
        # Create save directory if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
    def _on_step(self):
        # Save model at regular intervals
        if self.num_timesteps >= self.last_save + self.save_freq:
            model_path = os.path.join(self.save_dir, f"{self.model_prefix}_{self.num_timesteps}")
            self.model.save(model_path)
            print(f"Model saved at {model_path}")
            self.last_save = self.num_timesteps
        
        # Log rewards and metrics
        current_reward = self.locals.get("rewards")[0] if self.locals.get("rewards") is not None else 0
        self.episode_total_reward += current_reward
        
        environment_info = self.locals.get("infos")[0] if self.locals.get("infos") is not None else {}
        episode_done = self.locals.get("dones")[0] if self.locals.get("dones") is not None else False
        
        # Track control costs
        if "reward_ctrl" in environment_info:
            self.control_costs += abs(environment_info["reward_ctrl"])
        
        if episode_done:
            distance_traveled = environment_info.get("x_position", 0)
            with open(self.log_filepath, "a") as log_file:
                log_file.write(f"{self.num_timesteps},{self.episode_total_reward:.4f},{distance_traveled:.4f},{self.control_costs:.4f}\n")
            self.episode_total_reward = 0
            self.control_costs = 0
        return True
    
    def _on_training_start(self):
        with open(self.log_filepath, "w") as log_file:
            log_file.write("timestep,reward,distance,control_cost\n")

class AntiInversionCheetahEnv(gym.Wrapper):
    def __init__(self):
        super().__init__(gym.make("HalfCheetah-v4"))
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        modified_reward = self.modified_reward_function(observation, action, original_reward)
        return observation, modified_reward, terminated, truncated, info
    
    def modified_reward_function(self, observation, action, original_reward):
        # Get TRUE torso angle (using the correct index)
        torso_angle = observation[1]  # rooty - actual torso angle
        
        # Simple posture penalty based on cosine of the angle
        posture_penalty = -1.0 * min(0, np.cos(torso_angle))
        
        # Original reward weight
        original_reward_weight = 1.0
        
        # Combined reward
        reward = posture_penalty + original_reward_weight * original_reward
        
        return reward

def train_anti_inversion_with_ppo():
    # Setup environment
    print("Creating anti-inversion cheetah environment...")
    cheetah_environment = AntiInversionCheetahEnv()

    # Initialize PPO model with default hyperparameters
    print("Initializing PPO model...")
    training_model = PPO(
        policy="MlpPolicy",
        env=cheetah_environment,
        verbose=1
    )

    # Setup logger with checkpoint saving capability
    print("Setting up training logger...")
    progress_logger = EnhancedTrainingLogger(
        log_filepath="anti_inversion_ppo_training2.txt",
        save_dir="model_checkpoints",
        save_freq=50000,
        model_prefix="anti_inversion_ppo2"
    )

    # Train the model
    print("Starting training for 1,000,000 timesteps...")
    training_model.learn(total_timesteps=1000000, callback=progress_logger)

    # Save the final model
    print("Saving final trained model...")
    training_model.save("anti_inversion_ppo_final2")

    print("Training completed!")
    print(f"Training logs saved to {progress_logger.log_filepath}")
    print(f"Model checkpoints saved in {progress_logger.save_dir}")

if __name__ == "__main__":
    train_anti_inversion_with_ppo()
# Out:
# Creating anti-inversion cheetah environment...
# /home/phalle.y/.local/lib/python3.8/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Initializing PPO model...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/phalle.y/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Setting up training logger...
# Starting training for 1,000,000 timesteps...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    fps             | 966      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009235426 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.5        |
# |    explained_variance   | -0.0168     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.998       |
# |    value_loss           | 77.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008167243 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.49       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.996       |
# |    value_loss           | 76.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008722721 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.994       |
# |    value_loss           | 31.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 308         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008409081 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.994       |
# |    value_loss           | 37.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 563          |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0065577216 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.48        |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 0.993        |
# |    value_loss           | 63           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 7           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006002741 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.47       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.992       |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007139915 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.47       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.994       |
# |    value_loss           | 70.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 9            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0095799025 |
# |    clip_fraction        | 0.0758       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.47        |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.9         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0193      |
# |    std                  | 0.992        |
# |    value_loss           | 77.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 554          |
# |    iterations           | 10           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0078663565 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.46        |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0148      |
# |    std                  | 0.991        |
# |    value_loss           | 87.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 242         |
# | time/                   |             |
# |    fps                  | 553         |
# |    iterations           | 11          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006216725 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.46       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.993       |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008709191 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.985       |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 551         |
# |    iterations           | 13          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008705568 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.42       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.983       |
# |    value_loss           | 69.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 14          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007034932 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.977       |
# |    value_loss           | 62.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 15          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010252709 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.37       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.975       |
# |    value_loss           | 66          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 292         |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 16          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012005245 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.33       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.967       |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 17          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009318616 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.96        |
# |    value_loss           | 79.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 18          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010351162 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.957       |
# |    value_loss           | 47.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 322        |
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 19         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01323139 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.24      |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.6       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0208    |
# |    std                  | 0.955      |
# |    value_loss           | 58.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 328        |
# | time/                   |            |
# |    fps                  | 503        |
# |    iterations           | 20         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01062513 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.23      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.7       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0238    |
# |    std                  | 0.951      |
# |    value_loss           | 41.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 352        |
# | time/                   |            |
# |    fps                  | 497        |
# |    iterations           | 21         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00964856 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.19      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12         |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0217    |
# |    std                  | 0.947      |
# |    value_loss           | 41.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 358         |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 22          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.032613166 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.16       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.94        |
# |    value_loss           | 33.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 371          |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 23           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0074289553 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.13        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.4         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 0.936        |
# |    value_loss           | 69           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 377         |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 24          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009240661 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.88        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.932       |
# |    value_loss           | 31.5        |
# -----------------------------------------
# Model saved at model_checkpoints/anti_inversion_ppo2_50000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 386          |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 25           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0076120785 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.07        |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.018       |
# |    std                  | 0.926        |
# |    value_loss           | 43.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 396         |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 26          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018158104 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.92        |
# |    value_loss           | 25.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 407         |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 27          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.018267285 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.93        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.922       |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 417         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 28          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013094679 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.925       |
# |    value_loss           | 21.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 423          |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 29           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0149594825 |
# |    clip_fraction        | 0.154        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.02        |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.46         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0248      |
# |    std                  | 0.919        |
# |    value_loss           | 15.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 426         |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 30          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010032533 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8          |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.58        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.916       |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 426          |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 31           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0079854885 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.99        |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.7         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0158      |
# |    std                  | 0.916        |
# |    value_loss           | 45.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 32          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004387236 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.7        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.915       |
# |    value_loss           | 87.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 441         |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 33          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009758761 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.53        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.91        |
# |    value_loss           | 28.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 445         |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 34          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009555472 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.909       |
# |    value_loss           | 32.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 450         |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 35          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014094515 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.904       |
# |    value_loss           | 32.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 453         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 36          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007111959 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.901       |
# |    value_loss           | 75.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 455         |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 37          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007989443 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.88       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.9         |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 462         |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 38          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013989634 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.891       |
# |    value_loss           | 23.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 469         |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 39          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019304622 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.84        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 0.882       |
# |    value_loss           | 14.4        |
# -----------------------------------------
