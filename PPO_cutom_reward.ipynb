# %%
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback


class CustomHalfCheetahEnv(gym.Wrapper):
    
    def __init__(self):
        env = gym.make("HalfCheetah-v4")
        super().__init__(env)
        
    def step(self, action):
        observation, original_reward, terminated, truncated, info = self.env.step(action)
        reward = self.modified_reward_function(observation, action, original_reward)
        return observation, reward, terminated, truncated, info
    
    def modified_reward_function(self, observation, action, original_reward):
    
    # Forward velocity reward (using x-coordinate velocity, index 8)
        forward_reward = 1.0 * observation[8]
    
    # Penalize excessive vertical movement (z-coordinate, index 0)
        height_penalty = -0.05 * abs(observation[0] - 0.5)  
    
    # Penalize excessive rotations for stability (angle of second rotor, index 2)
        rotation_penalty = -0.1 * abs(observation[2])  
    
    # Energy efficiency - penalize excessive joint movements
    # Angular velocities from indices 10-16
        energy_penalty = -0.001 * sum(abs(observation[i]) for i in range(10, 17))
    
    # Smooth control - penalize large action changes
        control_penalty = -0.01 * np.sum(np.square(action))
    
    # Balance original reward with custom components
        original_reward_weight = 0.5
    
    # Combined reward
        reward = (
            forward_reward +
            height_penalty +
            rotation_penalty +
            energy_penalty +
            control_penalty +
            original_reward_weight * original_reward
        )
    
        return reward


env = CustomHalfCheetahEnv()
    
model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
    )
    
    
    
checkpoint_callback = CheckpointCallback(save_freq=100000, save_path='./logs/',
                                           name_prefix='ppo_halfcheetah')

model.learn(total_timesteps=1000000, callback=checkpoint_callback)

       
    
print("Training completed!")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -330     |
# | time/              |          |
# |    fps             | 745      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -387        |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009496237 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.52       |
# |    explained_variance   | -0.0274     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 1           |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -403        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008520275 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.51       |
# |    explained_variance   | 0.00199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 0.998       |
# |    value_loss           | 95.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -428         |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 4            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073115835 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.5         |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.9         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0156      |
# |    std                  | 0.996        |
# |    value_loss           | 99.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -425         |
# | time/                   |              |
# |    fps                  | 507          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0066016065 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.49        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.995        |
# |    value_loss           | 128          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -414        |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008101467 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.993       |
# |    value_loss           | 78.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -415        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 7           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011744268 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | -0.103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0295     |
# |    std                  | 0.987       |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -383        |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 8           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006144316 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.43       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.985       |
# |    value_loss           | 86.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -376        |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 9           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008589264 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.982       |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -391        |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 10          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007848483 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.976       |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -372        |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 11          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006667909 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.37       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.977       |
# |    value_loss           | 96.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -370        |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 12          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008156037 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.38       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.979       |
# |    value_loss           | 66.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -359         |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 13           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0085552875 |
# |    clip_fraction        | 0.0893       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.36        |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0215      |
# |    std                  | 0.972        |
# |    value_loss           | 35           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -356        |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 14          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009013055 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.33       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.967       |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -350        |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 15          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009631228 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.31       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.967       |
# |    value_loss           | 33.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -342        |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 16          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012319379 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.31       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.82        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.964       |
# |    value_loss           | 26.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 17          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009548153 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.955       |
# |    value_loss           | 21          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -330       |
# | time/                   |            |
# |    fps                  | 480        |
# |    iterations           | 18         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01208337 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.22      |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.7       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0307    |
# |    std                  | 0.952      |
# |    value_loss           | 24.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -325        |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 19          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011132497 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0314     |
# |    std                  | 0.953       |
# |    value_loss           | 23.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 20          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011987701 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.19       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.5         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.944       |
# |    value_loss           | 21          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 21          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006609929 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.17       |
# |    explained_variance   | 0.376       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.945       |
# |    value_loss           | 71.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -326        |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 22          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011210512 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.16       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.942       |
# |    value_loss           | 33.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -324        |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 23          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008044805 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.94        |
# |    value_loss           | 46.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -321       |
# | time/                   |            |
# |    fps                  | 478        |
# |    iterations           | 24         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01465438 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.13      |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.5       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0368    |
# |    std                  | 0.937      |
# |    value_loss           | 26         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -322       |
# | time/                   |            |
# |    fps                  | 478        |
# |    iterations           | 25         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00935681 |
# |    clip_fraction        | 0.099      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.11      |
# |    explained_variance   | 0.505      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29.9       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0247    |
# |    std                  | 0.935      |
# |    value_loss           | 72.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -319       |
# | time/                   |            |
# |    fps                  | 478        |
# |    iterations           | 26         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01135444 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.07      |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.1       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0313    |
# |    std                  | 0.925      |
# |    value_loss           | 34.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 27          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010838008 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.917       |
# |    value_loss           | 36.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -314         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 28           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0142383035 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.98        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.2         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.041       |
# |    std                  | 0.915        |
# |    value_loss           | 24.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 29          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012980543 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | -0.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0353     |
# |    std                  | 0.914       |
# |    value_loss           | 51.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -316        |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 30          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009325387 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0287     |
# |    std                  | 0.911       |
# |    value_loss           | 57.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -310         |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 31           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0139217125 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.91        |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.1         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0397      |
# |    std                  | 0.902        |
# |    value_loss           | 32.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -305       |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 32         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01042413 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.88      |
# |    explained_variance   | 0.575      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.8       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0286    |
# |    std                  | 0.898      |
# |    value_loss           | 50.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -298       |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 33         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01171908 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.86      |
# |    explained_variance   | 0.505      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.3       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0332    |
# |    std                  | 0.896      |
# |    value_loss           | 50.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 34          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015142614 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.82       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0368     |
# |    std                  | 0.889       |
# |    value_loss           | 34          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -292         |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 35           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0110615315 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.78        |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0318      |
# |    std                  | 0.885        |
# |    value_loss           | 55.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 36          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012493152 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0346     |
# |    std                  | 0.884       |
# |    value_loss           | 59.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -289        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 37          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013417517 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.76       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.881       |
# |    value_loss           | 41.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -285        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 38          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.020434879 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.71       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0426     |
# |    std                  | 0.871       |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 39          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.016307041 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0433     |
# |    std                  | 0.865       |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -277        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 40          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012722655 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.861       |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -273        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 41          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.016495677 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.59       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.62        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0437     |
# |    std                  | 0.856       |
# |    value_loss           | 31.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -267        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 42          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015147831 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0416     |
# |    std                  | 0.85        |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -265        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 43          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015409915 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.52       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0386     |
# |    std                  | 0.848       |
# |    value_loss           | 57.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -259        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 44          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016028281 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.5        |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0396     |
# |    std                  | 0.844       |
# |    value_loss           | 45.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -251        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 45          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013425903 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.47       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.8        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0371     |
# |    std                  | 0.839       |
# |    value_loss           | 53.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -247        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 46          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.020193271 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.41       |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0462     |
# |    std                  | 0.829       |
# |    value_loss           | 38.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -240        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 47          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.022226706 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.048      |
# |    std                  | 0.819       |
# |    value_loss           | 30.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -233        |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 48          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.023561459 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.26       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.61        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0521     |
# |    std                  | 0.808       |
# |    value_loss           | 27.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -224        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 49          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.024660002 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.18       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0512     |
# |    std                  | 0.797       |
# |    value_loss           | 26.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -214        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 50          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.024661703 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0491     |
# |    std                  | 0.79        |
# |    value_loss           | 29.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -206        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 51          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.020110013 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0463     |
# |    std                  | 0.789       |
# |    value_loss           | 29.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -197         |
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 52           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0119774565 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.06        |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.7         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0356      |
# |    std                  | 0.785        |
# |    value_loss           | 67.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 53          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 108544      |
# ...
# | train/                  |            |
# |    approx_kl            | 0.08999274 |
# |    clip_fraction        | 0.501      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.92       |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.08       |
# |    n_updates            | 4710       |
# |    policy_gradient_loss | -0.0206    |
# |    std                  | 0.183      |
# |    value_loss           | 12.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 473        |
# |    time_elapsed         | 2103       |
# |    total_timesteps      | 968704     |
# | train/                  |            |
# |    approx_kl            | 0.07374362 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.93       |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.27       |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0129    |
# |    std                  | 0.182      |
# |    value_loss           | 14.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 474        |
# |    time_elapsed         | 2108       |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.06002171 |
# |    clip_fraction        | 0.457      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.94       |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.6       |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.02      |
# |    std                  | 0.183      |
# |    value_loss           | 17.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 475        |
# |    time_elapsed         | 2112       |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.08484942 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.92       |
# |    explained_variance   | 0.7        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.77       |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.0059    |
# |    std                  | 0.184      |
# |    value_loss           | 10.4       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 2.36e+03  |
# | time/                   |           |
# |    fps                  | 460       |
# |    iterations           | 476       |
# |    time_elapsed         | 2117      |
# |    total_timesteps      | 974848    |
# | train/                  |           |
# |    approx_kl            | 0.0820138 |
# |    clip_fraction        | 0.528     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.93      |
# |    explained_variance   | 0.879     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.1       |
# |    n_updates            | 4750      |
# |    policy_gradient_loss | -0.0132   |
# |    std                  | 0.183     |
# |    value_loss           | 10.4      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.36e+03    |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 477         |
# |    time_elapsed         | 2121        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.067294165 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.95        |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.51        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.183       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 478        |
# |    time_elapsed         | 2126       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.07737139 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.97       |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.18       |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.00826   |
# |    std                  | 0.182      |
# |    value_loss           | 10.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 479        |
# |    time_elapsed         | 2130       |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.07689048 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.98       |
# |    explained_variance   | 0.835      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.4       |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.182      |
# |    value_loss           | 18.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.36e+03    |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 480         |
# |    time_elapsed         | 2135        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.061429985 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2           |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.55        |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.181       |
# |    value_loss           | 19.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 481        |
# |    time_elapsed         | 2139       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.06660473 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.99       |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.04       |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.181      |
# |    value_loss           | 22.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.36e+03    |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 482         |
# |    time_elapsed         | 2144        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.093080565 |
# |    clip_fraction        | 0.555       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2           |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.77        |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00593    |
# |    std                  | 0.181       |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 483        |
# |    time_elapsed         | 2148       |
# |    total_timesteps      | 989184     |
# | train/                  |            |
# |    approx_kl            | 0.05730907 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.01       |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.7       |
# |    n_updates            | 4820       |
# |    policy_gradient_loss | -0.018     |
# |    std                  | 0.181      |
# |    value_loss           | 66.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.36e+03    |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 484         |
# |    time_elapsed         | 2153        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.119884714 |
# |    clip_fraction        | 0.575       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.01        |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.181       |
# |    value_loss           | 11.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 485        |
# |    time_elapsed         | 2157       |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.06337532 |
# |    clip_fraction        | 0.444      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2          |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.34       |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0248    |
# |    std                  | 0.181      |
# |    value_loss           | 29.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 486        |
# |    time_elapsed         | 2162       |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.08656054 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.02       |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.13       |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0153    |
# |    std                  | 0.181      |
# |    value_loss           | 16.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 487        |
# |    time_elapsed         | 2166       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.07806473 |
# |    clip_fraction        | 0.49       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.03       |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.18       |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0201    |
# |    std                  | 0.18       |
# |    value_loss           | 17.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.36e+03   |
# | time/                   |            |
# |    fps                  | 460        |
# |    iterations           | 488        |
# |    time_elapsed         | 2171       |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.13914487 |
# |    clip_fraction        | 0.641      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.03       |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.77       |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | 0.00511    |
# |    std                  | 0.181      |
# |    value_loss           | 8.45       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.36e+03    |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 489         |
# |    time_elapsed         | 2175        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.061967693 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.04        |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.18        |
# |    value_loss           | 29          |
# -----------------------------------------
# Training completed!
